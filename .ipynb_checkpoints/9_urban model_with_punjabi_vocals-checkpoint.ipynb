# %%
import librosa
import os
import numpy as np
import glob
import matplotlib.pyplot as plt
import tensorflow as tf
from matplotlib.pyplot import specgram
from sklearn.model_selection import train_test_split
from tensorflow.contrib import keras
from tensorflow.contrib.keras import models
from tensorflow.contrib.keras import layers
from tensorflow.contrib.keras import regularizers
from sklearn import preprocessing
# %matplotlib inline
plt.style.use('ggplot')

plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = 'Ubuntu'
plt.rcParams['font.monospace'] = 'Ubuntu Mono'
plt.rcParams['font.size'] = 12
plt.rcParams['axes.labelsize'] = 11
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['axes.titlesize'] = 14
plt.rcParams['xtick.labelsize'] = 10
plt.rcParams['ytick.labelsize'] = 10
plt.rcParams['legend.fontsize'] = 11
plt.rcParams['figure.titlesize'] = 13

# %% [markdown]
# ## Preprocessing

# %%
le = preprocessing.LabelEncoder()
encoder_is_fit = False

def extract_feature(file_name, printLog = False):
    X, sample_rate = librosa.load(file_name)
    stft = np.abs(librosa.stft(X))
    mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=20).T,axis=0)
#     delta = librosa.feature.delta
    chroma = np.sum(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0) # stft used
#     mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
#     contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate).T,axis=0) # stft used
    tonnetz = np.mean(librosa.feature.tonnetz(y=librosa.effects.harmonic(X),
      sr=sample_rate).T,axis=0)
#     ext_features = np.hstack([mfccs,chroma,mel,contrast,tonnetz])
    ext_features = np.hstack([mfccs,chroma,tonnetz])
    if printLog:
      print('sample rate = %s'%sample_rate)
      print('mfccs shape = %s'%mfccs.shape)
      print('chroma shape = %s'%chroma.shape)
#       print('mel shape = %s'%mel.shape)
#       print('contrast shape = %s'%contrast.shape)
      print('tonnetz shape = %s'%tonnetz.shape)
    return ext_features

def parse_audio_files(root_path, log=False):
#     fts, labels = np.empty((0,193), dtype=np.float32), np.empty((0))
    fts, labels = np.empty((0,38), dtype=np.float32), np.empty((0))
    folders = (os.path.join(root_path,f) for f in os.listdir(root_path) 
                  if (os.path.isdir(os.path.join(root_path,f)) and not f.startswith('.')
                     and not f.startswith('hawker')))
    for fldr in folders:
        wave_files = (os.path.join(fldr, f) for f in os.listdir(fldr) if (f.endswith('.wav') 
            and os.path.isfile(os.path.join(fldr, f))))
        if log:
          print('\n\nnavigating in the folder = %s'%str(fldr))
        for f in wave_files:
              if log:
                print(str(f))
              ext_features = extract_feature(f)
              fts = np.vstack([fts,ext_features])
              labels = np.append(labels, os.path.basename(fldr))
    return fts,labels

def one_hot_encode(labels, force_fit=False):
    global encoder_is_fit
    global encoded_labels
    if force_fit or not encoder_is_fit:
        encoded_labels = le.fit_transform(labels)
        encoder_is_fit = True
    else:
        encoded_labels = le.transform(labels)
    one_hot_encode = keras.utils.to_categorical(encoded_labels)
    return one_hot_encode

# %%
y, sr = librosa.load(librosa.util.example_audio_file())

# %%
ex = librosa.feature.mfcc(y=y[:sr], sr=sr)

# %%
ex.shape
# Out:
# (20, 44)

# %%
audio,sr = librosa.load('../notebook/sounds/recorded/large/ah_drakht_boht_sohna_lag_reha/1.wav')
mfcc = librosa.feature.mfcc(y=audio[:sr], sr=sr, n_mfcc=20)

# %%
mfcc.shape
# Out:
# (20, 44)

# %%
features1 = extract_feature('../notebook/sounds/recorded/large/ah_drakht_boht_sohna_lag_reha/1.wav', printLog=True)
features2 = extract_feature('../notebook/sounds/recorded/large/ah_drakht_boht_sohna_lag_reha/2.wav', printLog=True)
print(features1.shape)
print(features2.shape)
# print(np.vstack([features1.shape,features2.shape]))
# Out:
# sample rate = 22050
# mfccs shape = 20
# chroma shape = 12
# tonnetz shape = 6
# sample rate = 22050
# mfccs shape = 20
# chroma shape = 12
# tonnetz shape = 6
# (38,)
# (38,)

# %%
def printFeatureDetails(wave_file_path):
    if os.path.exists(wave_file_path):
        x,y = librosa.load(wave_file_path)
        stft = np.abs(librosa.stft(x))
        chroma = librosa.feature.chroma_stft(S=stft, sr=y)
        print('x.shape = %s, y = %d'%(str(x.shape), y))
        print('stft.shape = %s'%str(stft.shape))
        print('chroma.shape = %s'%str(chroma.shape))
    else:
        print('file \'%s\' doesn\'t exist'%wave_file_path)

# %%
np.random.seed(341136787)
def randomize(dataset, labels):
  permutation = np.random.permutation(labels.shape[0])
  shuffled_dataset = dataset[permutation,:]
  shuffled_labels = labels[permutation]
  return shuffled_dataset, shuffled_labels

# %%
#define paths
root_path_large = 'sounds/recorded/large'
root_path_small = 'sounds/recorded/small'

#extract features
train_x, train_y = parse_audio_files(root_path_large)
test_x, test_y = parse_audio_files(root_path_small)

# %%
#randomize
train_x, train_y = randomize(train_x, train_y)
test_x, test_y = randomize(test_x, test_y)

#one hot encode the labels
train_y = one_hot_encode(train_y)
test_y = one_hot_encode(test_y)

# %% [markdown]
# ## Save pickle

# %%
# dump to pickle
if os.environ['HOME'] == '/Users/Gundeep':
    pickle_filename = '/Users/Gundeep/Projects/Punjabi/punjabi_pickle.pickle'
else:
    pickle_filename = '/home/paperspace/Documents/Projects/Punjabi/punjabi_pickle.pickle'
pickle_dump = {'train_x' : train_x,
               'train_y' : train_y,
               'test_x' : test_x,
               'test_y' : test_y}
import pickle
try:
  with open(pickle_filename, 'wb') as f:
    pickle.dump(pickle_dump, f, pickle.HIGHEST_PROTOCOL)
except Exception as e:
  print('Unable to save data to', pickle_filename, ':', e)

# %%
os.environ['HOME']
# Out:
# '/home/paperspace'

# %% [markdown]
# ## Load pickle

# %%
# load from pickle
import pickle
pickle_filename = ''
if os.environ['HOME'] == '/Users/Gundeep':
    pickle_filename = '/Users/Gundeep/Projects/Punjabi/punjabi_pickle.pickle'
else:
    pickle_filename = '/home/paperspace/Documents/Projects/Punjabi/punjabi_pickle.pickle'
pickle_dump = {}
try:
  with open(pickle_filename, 'rb') as f:
    pickle_dump = pickle.load(f)
except Exception as e:
  print('Unable to load pickle', pickle_filename, ':', e)

# %%
train_x = pickle_dump['train_x']
train_y = pickle_dump['train_y']
test_x = pickle_dump['test_x']
test_y = pickle_dump['test_y']

# %%
print('train_x.shape = %s'%str(train_x.shape))
print('train_y.shape = %s'%str(train_y.shape))
print('test_x.shape = %s'%str(test_x.shape))
print('test_y.shape = %s'%str(test_y.shape))
# Out:
# train_x.shape = (670, 38)
# train_y.shape = (670, 9)
# test_x.shape = (19, 38)
# test_y.shape = (19, 9)

# %% [markdown]
# ## Model Training

# %%
# imports
from keras.metrics import categorical_accuracy
Sequential = models.Sequential
Dense = layers.Dense
Dropout = layers.Dropout

#numpy.random.seed(7)

# enable tensorflow logging
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
# Out:
# Using TensorFlow backend.

# %%
global training_epochs
global n_dim
global b_size
global n_classes
global n_hidden_units_one
global n_hidden_units_two
global sd
global learning_rate
def load_hp():
    #hyper paramters
    global training_epochs
    global n_dim
    global b_size
    global n_classes
    global n_hidden_units_one
    global n_hidden_units_two
    global sd
    global learning_rate
    training_epochs = 1000
    n_dim = train_x.shape[1]
    b_size = 10
    n_classes = 9
    n_hidden_units_one = 64
    n_hidden_units_two = 32
    sd = 1 / np.sqrt(n_dim)
    learning_rate = 0.0007

# %%
def create_model():
    model = None
    model = Sequential()
    model.add(Dense(n_hidden_units_one, input_dim=n_dim, activation='relu', kernel_regularizer=regularizers.l2(0.002)))
    model.add(Dropout(0.15))
    model.add(Dense(n_hidden_units_two, activation='relu', kernel_regularizer=regularizers.l2(0.002)))
    model.add(Dense(n_classes, activation='softmax'))
    return model

# %%
def train_model(model,train_x,train_y,split=0.3,epochs=training_epochs):
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[categorical_accuracy])
    return model.fit(train_x, train_y, epochs=epochs, validation_split=split, batch_size=b_size)

# %%
# train model for different number of training examples
min_num = 69
max_num = train_x.shape[0]
fine_tuning = 60
t_num = np.arange(min_num, max_num, fine_tuning)

# load the model
load_hp()
model = create_model()

# run model for different number of training examples
loss_values = np.zeros(len(t_num))
val_loss_values = np.zeros(len(t_num))
acc_values = np.zeros(len(t_num))
val_acc_values = np.zeros(len(t_num))

for i,nm in enumerate(t_num):
    model_hist = train_model(model,train_x[:nm],train_y[:nm])
    acc_values[i] = model_hist.history['categorical_accuracy'][-1]
    val_acc_values[i] = model_hist.history['val_categorical_accuracy'][-1]
    loss_values[i] = model_hist.history['loss'][-1]
    val_loss_values[i] = model_hist.history['val_loss'][-1]
# Out:
# Train on 48 samples, validate on 21 samples
# Epoch 1/1000
# 48/48 [==============================] - 0s - loss: 3.0170 - categorical_accuracy: 0.0417 - val_loss: 2.9137 - val_categorical_accuracy: 0.1905
# Epoch 2/1000
# 48/48 [==============================] - 0s - loss: 3.0903 - categorical_accuracy: 0.0833 - val_loss: 3.0379 - val_categorical_accuracy: 0.1905
# Epoch 3/1000
# 48/48 [==============================] - 0s - loss: 3.4090 - categorical_accuracy: 0.0417 - val_loss: 2.9209 - val_categorical_accuracy: 0.1905
# Epoch 4/1000
# 48/48 [==============================] - 0s - loss: 3.1366 - categorical_accuracy: 0.0417 - val_loss: 2.9457 - val_categorical_accuracy: 0.1429
# Epoch 5/1000
# 48/48 [==============================] - 0s - loss: 2.9088 - categorical_accuracy: 0.1250 - val_loss: 3.2133 - val_categorical_accuracy: 0.1429
# Epoch 6/1000
# 48/48 [==============================] - 0s - loss: 3.0705 - categorical_accuracy: 0.1042 - val_loss: 3.2094 - val_categorical_accuracy: 0.1429
# Epoch 7/1000
# 48/48 [==============================] - 0s - loss: 3.2266 - categorical_accuracy: 0.1250 - val_loss: 3.2057 - val_categorical_accuracy: 0.1429
# Epoch 8/1000
# 48/48 [==============================] - 0s - loss: 2.9758 - categorical_accuracy: 0.1458 - val_loss: 3.2023 - val_categorical_accuracy: 0.1429
# Epoch 9/1000
# 48/48 [==============================] - 0s - loss: 2.5182 - categorical_accuracy: 0.1667 - val_loss: 1.5784 - val_categorical_accuracy: 0.1905
# Epoch 10/1000
# 48/48 [==============================] - 0s - loss: 2.4005 - categorical_accuracy: 0.1875 - val_loss: 2.3396 - val_categorical_accuracy: 0.0476
# Epoch 11/1000
# 48/48 [==============================] - 0s - loss: 2.8690 - categorical_accuracy: 0.1042 - val_loss: 1.9690 - val_categorical_accuracy: 0.0952
# Epoch 12/1000
# 48/48 [==============================] - 0s - loss: 2.4421 - categorical_accuracy: 0.1875 - val_loss: 2.1436 - val_categorical_accuracy: 0.0952
# Epoch 13/1000
# 48/48 [==============================] - 0s - loss: 2.1221 - categorical_accuracy: 0.2292 - val_loss: 2.2991 - val_categorical_accuracy: 0.1429
# Epoch 14/1000
# 48/48 [==============================] - 0s - loss: 2.6679 - categorical_accuracy: 0.1250 - val_loss: 3.1859 - val_categorical_accuracy: 0.1429
# Epoch 15/1000
# 48/48 [==============================] - 0s - loss: 2.9332 - categorical_accuracy: 0.1250 - val_loss: 3.1837 - val_categorical_accuracy: 0.1429
# Epoch 16/1000
# 48/48 [==============================] - 0s - loss: 2.4567 - categorical_accuracy: 0.1458 - val_loss: 1.7909 - val_categorical_accuracy: 0.1905
# Epoch 17/1000
# 48/48 [==============================] - 0s - loss: 2.6630 - categorical_accuracy: 0.1458 - val_loss: 3.3113 - val_categorical_accuracy: 0.0952
# Epoch 18/1000
# 48/48 [==============================] - 0s - loss: 2.6324 - categorical_accuracy: 0.1875 - val_loss: 2.5368 - val_categorical_accuracy: 0.0952
# Epoch 19/1000
# 48/48 [==============================] - 0s - loss: 2.5036 - categorical_accuracy: 0.1875 - val_loss: 2.6759 - val_categorical_accuracy: 0.0952
# Epoch 20/1000
# 48/48 [==============================] - 0s - loss: 2.6281 - categorical_accuracy: 0.1458 - val_loss: 3.2163 - val_categorical_accuracy: 0.0952
# Epoch 21/1000
# 48/48 [==============================] - 0s - loss: 2.6748 - categorical_accuracy: 0.1875 - val_loss: 3.3429 - val_categorical_accuracy: 0.0952
# Epoch 22/1000
# 48/48 [==============================] - 0s - loss: 2.5435 - categorical_accuracy: 0.2083 - val_loss: 3.3415 - val_categorical_accuracy: 0.0952
# Epoch 23/1000
# 48/48 [==============================] - 0s - loss: 2.6624 - categorical_accuracy: 0.1458 - val_loss: 3.3402 - val_categorical_accuracy: 0.0952
# Epoch 24/1000
# 48/48 [==============================] - 0s - loss: 2.6383 - categorical_accuracy: 0.1667 - val_loss: 3.3389 - val_categorical_accuracy: 0.0952
# Epoch 25/1000
# 48/48 [==============================] - 0s - loss: 2.5485 - categorical_accuracy: 0.2292 - val_loss: 3.2878 - val_categorical_accuracy: 0.0952
# Epoch 26/1000
# 48/48 [==============================] - 0s - loss: 2.4622 - categorical_accuracy: 0.2083 - val_loss: 1.8673 - val_categorical_accuracy: 0.0476
# Epoch 27/1000
# 48/48 [==============================] - 0s - loss: 2.6236 - categorical_accuracy: 0.0625 - val_loss: 2.3039 - val_categorical_accuracy: 0.0000e+00
# Epoch 28/1000
# 48/48 [==============================] - 0s - loss: 2.3917 - categorical_accuracy: 0.1042 - val_loss: 3.1910 - val_categorical_accuracy: 0.0000e+00
# Epoch 29/1000
# 48/48 [==============================] - 0s - loss: 2.5377 - categorical_accuracy: 0.1250 - val_loss: 2.7213 - val_categorical_accuracy: 0.0000e+00
# Epoch 30/1000
# 48/48 [==============================] - 0s - loss: 2.3337 - categorical_accuracy: 0.1667 - val_loss: 1.9350 - val_categorical_accuracy: 0.0952
# Epoch 31/1000
# 48/48 [==============================] - 0s - loss: 2.5489 - categorical_accuracy: 0.0417 - val_loss: 1.8397 - val_categorical_accuracy: 0.0000e+00
# Epoch 32/1000
# 48/48 [==============================] - 0s - loss: 2.3717 - categorical_accuracy: 0.1250 - val_loss: 1.8122 - val_categorical_accuracy: 0.0476
# Epoch 33/1000
# 48/48 [==============================] - 0s - loss: 2.3916 - categorical_accuracy: 0.1250 - val_loss: 2.1789 - val_categorical_accuracy: 0.0952
# Epoch 34/1000
# 48/48 [==============================] - 0s - loss: 2.2018 - categorical_accuracy: 0.1875 - val_loss: 3.2547 - val_categorical_accuracy: 0.0952
# Epoch 35/1000
# 48/48 [==============================] - 0s - loss: 2.4850 - categorical_accuracy: 0.1875 - val_loss: 2.9151 - val_categorical_accuracy: 0.0952
# Epoch 36/1000
# 48/48 [==============================] - 0s - loss: 2.2158 - categorical_accuracy: 0.1667 - val_loss: 1.9708 - val_categorical_accuracy: 0.0952
# Epoch 37/1000
# 48/48 [==============================] - 0s - loss: 2.0303 - categorical_accuracy: 0.1250 - val_loss: 1.8658 - val_categorical_accuracy: 0.0476
# Epoch 38/1000
# 48/48 [==============================] - 0s - loss: 2.4075 - categorical_accuracy: 0.0625 - val_loss: 2.5335 - val_categorical_accuracy: 0.0000e+00
# Epoch 39/1000
# 48/48 [==============================] - 0s - loss: 2.3593 - categorical_accuracy: 0.0833 - val_loss: 2.0102 - val_categorical_accuracy: 0.0000e+00
# Epoch 40/1000
# 48/48 [==============================] - 0s - loss: 2.0621 - categorical_accuracy: 0.1042 - val_loss: 1.9156 - val_categorical_accuracy: 0.0952
# Epoch 41/1000
# 48/48 [==============================] - 0s - loss: 2.0736 - categorical_accuracy: 0.1250 - val_loss: 1.8143 - val_categorical_accuracy: 0.0952
# Epoch 42/1000
# 48/48 [==============================] - 0s - loss: 2.2290 - categorical_accuracy: 0.0417 - val_loss: 2.3676 - val_categorical_accuracy: 0.0000e+00
# Epoch 43/1000
# 48/48 [==============================] - 0s - loss: 2.3409 - categorical_accuracy: 0.1667 - val_loss: 2.5280 - val_categorical_accuracy: 0.0000e+00
# Epoch 44/1000
# 48/48 [==============================] - 0s - loss: 2.1647 - categorical_accuracy: 0.1042 - val_loss: 1.7944 - val_categorical_accuracy: 0.1905
# Epoch 45/1000
# 48/48 [==============================] - 0s - loss: 2.3548 - categorical_accuracy: 0.0208 - val_loss: 1.7028 - val_categorical_accuracy: 0.1905
# Epoch 46/1000
# 48/48 [==============================] - 0s - loss: 2.1529 - categorical_accuracy: 0.0833 - val_loss: 2.3195 - val_categorical_accuracy: 0.0000e+00
# Epoch 47/1000
# 48/48 [==============================] - 0s - loss: 2.1800 - categorical_accuracy: 0.0833 - val_loss: 1.8553 - val_categorical_accuracy: 0.0952
# Epoch 48/1000
# 48/48 [==============================] - 0s - loss: 2.1328 - categorical_accuracy: 0.1042 - val_loss: 1.9303 - val_categorical_accuracy: 0.1905
# Epoch 49/1000
# 48/48 [==============================] - 0s - loss: 2.1598 - categorical_accuracy: 0.1042 - val_loss: 2.1242 - val_categorical_accuracy: 0.0000e+00
# Epoch 50/1000
# 48/48 [==============================] - 0s - loss: 2.2352 - categorical_accuracy: 0.0833 - val_loss: 1.7439 - val_categorical_accuracy: 0.1905
# Epoch 51/1000
# 48/48 [==============================] - 0s - loss: 2.0551 - categorical_accuracy: 0.1042 - val_loss: 1.6637 - val_categorical_accuracy: 0.1905
# Epoch 52/1000
# 48/48 [==============================] - 0s - loss: 2.1785 - categorical_accuracy: 0.0208 - val_loss: 2.0545 - val_categorical_accuracy: 0.0000e+00
# Epoch 53/1000
# 48/48 [==============================] - ETA: 0s - loss: 2.2155 - categorical_accuracy: 0.10 - 0s - loss: 2.0570 - categorical_accuracy: 0.1042 - val_loss: 1.7425 - val_categorical_accuracy: 0.0952
# Epoch 54/1000
# 48/48 [==============================] - 0s - loss: 2.0645 - categorical_accuracy: 0.0625 - val_loss: 1.6538 - val_categorical_accuracy: 0.1905
# Epoch 55/1000
# 48/48 [==============================] - 0s - loss: 2.1040 - categorical_accuracy: 0.0417 - val_loss: 1.7393 - val_categorical_accuracy: 0.1905
# Epoch 56/1000
# 48/48 [==============================] - 0s - loss: 2.0603 - categorical_accuracy: 0.1250 - val_loss: 1.7415 - val_categorical_accuracy: 0.0952
# Epoch 57/1000
# 48/48 [==============================] - 0s - loss: 1.9686 - categorical_accuracy: 0.1458 - val_loss: 1.8422 - val_categorical_accuracy: 0.0000e+00
# Epoch 58/1000
# 48/48 [==============================] - 0s - loss: 2.0230 - categorical_accuracy: 0.0625 - val_loss: 1.6685 - val_categorical_accuracy: 0.1905
# Epoch 59/1000
# 48/48 [==============================] - 0s - loss: 1.8178 - categorical_accuracy: 0.1458 - val_loss: 2.0286 - val_categorical_accuracy: 0.0000e+00
# Epoch 60/1000
# 48/48 [==============================] - 0s - loss: 1.9462 - categorical_accuracy: 0.0625 - val_loss: 1.6053 - val_categorical_accuracy: 0.0476
# Epoch 61/1000
# 48/48 [==============================] - 0s - loss: 1.7880 - categorical_accuracy: 0.1250 - val_loss: 1.5387 - val_categorical_accuracy: 0.0952
# Epoch 62/1000
# 48/48 [==============================] - 0s - loss: 2.0153 - categorical_accuracy: 0.0625 - val_loss: 1.6696 - val_categorical_accuracy: 0.0000e+00
# Epoch 63/1000
# 48/48 [==============================] - 0s - loss: 1.9098 - categorical_accuracy: 0.0417 - val_loss: 1.7960 - val_categorical_accuracy: 0.0000e+00
# Epoch 64/1000
# 48/48 [==============================] - 0s - loss: 1.9263 - categorical_accuracy: 0.0208 - val_loss: 1.6278 - val_categorical_accuracy: 0.0952
# Epoch 65/1000
# 48/48 [==============================] - 0s - loss: 1.8713 - categorical_accuracy: 0.1250 - val_loss: 1.6983 - val_categorical_accuracy: 0.0000e+00
# Epoch 66/1000
# 48/48 [==============================] - 0s - loss: 1.9403 - categorical_accuracy: 0.0417 - val_loss: 1.6377 - val_categorical_accuracy: 0.0476
# Epoch 67/1000
# 48/48 [==============================] - 0s - loss: 1.9156 - categorical_accuracy: 0.0833 - val_loss: 1.5945 - val_categorical_accuracy: 0.0476
# Epoch 68/1000
# 48/48 [==============================] - 0s - loss: 1.8710 - categorical_accuracy: 0.1042 - val_loss: 1.8273 - val_categorical_accuracy: 0.0000e+00
# Epoch 69/1000
# 48/48 [==============================] - 0s - loss: 1.8265 - categorical_accuracy: 0.0833 - val_loss: 1.6592 - val_categorical_accuracy: 0.0000e+00
# Epoch 70/1000
# 48/48 [==============================] - 0s - loss: 1.8153 - categorical_accuracy: 0.0833 - val_loss: 1.5566 - val_categorical_accuracy: 0.1905
# Epoch 71/1000
# 48/48 [==============================] - 0s - loss: 1.8370 - categorical_accuracy: 0.0208 - val_loss: 1.7061 - val_categorical_accuracy: 0.0000e+00
# Epoch 72/1000
# 48/48 [==============================] - 0s - loss: 1.8257 - categorical_accuracy: 0.1250 - val_loss: 1.6337 - val_categorical_accuracy: 0.0000e+00
# Epoch 73/1000
# 48/48 [==============================] - 0s - loss: 1.8639 - categorical_accuracy: 0.0625 - val_loss: 1.5369 - val_categorical_accuracy: 0.1905
# Epoch 74/1000
# 48/48 [==============================] - 0s - loss: 1.8559 - categorical_accuracy: 0.1458 - val_loss: 1.6980 - val_categorical_accuracy: 0.0000e+00
# Epoch 75/1000
# 48/48 [==============================] - 0s - loss: 1.8479 - categorical_accuracy: 0.1250 - val_loss: 1.6594 - val_categorical_accuracy: 0.0000e+00
# Epoch 76/1000
# 48/48 [==============================] - 0s - loss: 1.8096 - categorical_accuracy: 0.1042 - val_loss: 1.5651 - val_categorical_accuracy: 0.1905
# Epoch 77/1000
# 48/48 [==============================] - 0s - loss: 1.9618 - categorical_accuracy: 0.0833 - val_loss: 1.5374 - val_categorical_accuracy: 0.1429
# Epoch 78/1000
# 48/48 [==============================] - 0s - loss: 1.8456 - categorical_accuracy: 0.0625 - val_loss: 1.7908 - val_categorical_accuracy: 0.0000e+00
# Epoch 79/1000
# 48/48 [==============================] - 0s - loss: 1.8321 - categorical_accuracy: 0.0417 - val_loss: 1.5585 - val_categorical_accuracy: 0.1905
# Epoch 80/1000
# 48/48 [==============================] - 0s - loss: 1.8444 - categorical_accuracy: 0.0208 - val_loss: 1.6116 - val_categorical_accuracy: 0.0476
# Epoch 81/1000
# 48/48 [==============================] - 0s - loss: 1.9384 - categorical_accuracy: 0.0833 - val_loss: 1.5694 - val_categorical_accuracy: 0.1905
# Epoch 82/1000
# 48/48 [==============================] - 0s - loss: 1.7580 - categorical_accuracy: 0.1250 - val_loss: 1.5770 - val_categorical_accuracy: 0.0952
# Epoch 83/1000
# 48/48 [==============================] - 0s - loss: 1.7510 - categorical_accuracy: 0.1250 - val_loss: 1.6552 - val_categorical_accuracy: 0.0000e+00
# Epoch 84/1000
# 48/48 [==============================] - 0s - loss: 1.7987 - categorical_accuracy: 0.1042 - val_loss: 1.4950 - val_categorical_accuracy: 0.1905
# Epoch 85/1000
# 48/48 [==============================] - 0s - loss: 1.8341 - categorical_accuracy: 0.0833 - val_loss: 1.5189 - val_categorical_accuracy: 0.1905
# Epoch 86/1000
# 48/48 [==============================] - 0s - loss: 1.7581 - categorical_accuracy: 0.1042 - val_loss: 1.5510 - val_categorical_accuracy: 0.1905
# Epoch 87/1000
# 48/48 [==============================] - 0s - loss: 1.7646 - categorical_accuracy: 0.1042 - val_loss: 1.5596 - val_categorical_accuracy: 0.1905
# Epoch 88/1000
# 48/48 [==============================] - 0s - loss: 1.7575 - categorical_accuracy: 0.1042 - val_loss: 1.5584 - val_categorical_accuracy: 0.1429
# Epoch 89/1000
# 48/48 [==============================] - 0s - loss: 1.7264 - categorical_accuracy: 0.1042 - val_loss: 1.5932 - val_categorical_accuracy: 0.0000e+00
# Epoch 90/1000
# 48/48 [==============================] - 0s - loss: 1.7470 - categorical_accuracy: 0.0833 - val_loss: 1.5060 - val_categorical_accuracy: 0.1905
# Epoch 91/1000
# 48/48 [==============================] - 0s - loss: 1.7652 - categorical_accuracy: 0.1250 - val_loss: 1.5630 - val_categorical_accuracy: 0.0000e+00
# Epoch 92/1000
# 48/48 [==============================] - 0s - loss: 1.7467 - categorical_accuracy: 0.1042 - val_loss: 1.5103 - val_categorical_accuracy: 0.1429
# Epoch 93/1000
# 48/48 [==============================] - 0s - loss: 1.7336 - categorical_accuracy: 0.0833 - val_loss: 1.5000 - val_categorical_accuracy: 0.1905
# Epoch 94/1000
# 48/48 [==============================] - 0s - loss: 1.7521 - categorical_accuracy: 0.1042 - val_loss: 1.5764 - val_categorical_accuracy: 0.0000e+00
# Epoch 95/1000
# 48/48 [==============================] - 0s - loss: 1.7579 - categorical_accuracy: 0.1042 - val_loss: 1.5557 - val_categorical_accuracy: 0.0000e+00
# Epoch 96/1000
# 48/48 [==============================] - 0s - loss: 1.7246 - categorical_accuracy: 0.1042 - val_loss: 1.5352 - val_categorical_accuracy: 0.1905
# Epoch 97/1000
# 48/48 [==============================] - 0s - loss: 1.7227 - categorical_accuracy: 0.1042 - val_loss: 1.5985 - val_categorical_accuracy: 0.0000e+00
# Epoch 98/1000
# 48/48 [==============================] - 0s - loss: 1.7387 - categorical_accuracy: 0.0833 - val_loss: 1.5265 - val_categorical_accuracy: 0.1905
# Epoch 99/1000
# 48/48 [==============================] - 0s - loss: 1.7435 - categorical_accuracy: 0.1250 - val_loss: 1.5325 - val_categorical_accuracy: 0.0000e+00
# Epoch 100/1000
# 48/48 [==============================] - 0s - loss: 1.7329 - categorical_accuracy: 0.1250 - val_loss: 1.5139 - val_categorical_accuracy: 0.0000e+00
# Epoch 101/1000
# 48/48 [==============================] - 0s - loss: 1.7375 - categorical_accuracy: 0.0208 - val_loss: 1.4898 - val_categorical_accuracy: 0.1429
# Epoch 102/1000
# 48/48 [==============================] - 0s - loss: 1.7740 - categorical_accuracy: 0.1250 - val_loss: 1.4832 - val_categorical_accuracy: 0.1429
# Epoch 103/1000
# 48/48 [==============================] - 0s - loss: 1.7024 - categorical_accuracy: 0.1042 - val_loss: 1.4924 - val_categorical_accuracy: 0.0476
# Epoch 104/1000
# 48/48 [==============================] - 0s - loss: 1.7084 - categorical_accuracy: 0.0833 - val_loss: 1.4976 - val_categorical_accuracy: 0.1429
# Epoch 105/1000
# 48/48 [==============================] - 0s - loss: 1.6862 - categorical_accuracy: 0.1042 - val_loss: 1.5403 - val_categorical_accuracy: 0.0000e+00
# Epoch 106/1000
# 48/48 [==============================] - 0s - loss: 1.7022 - categorical_accuracy: 0.1667 - val_loss: 1.5275 - val_categorical_accuracy: 0.1905
# Epoch 107/1000
# 48/48 [==============================] - 0s - loss: 1.7263 - categorical_accuracy: 0.1042 - val_loss: 1.5616 - val_categorical_accuracy: 0.0000e+00
# Epoch 108/1000
# 48/48 [==============================] - 0s - loss: 1.7045 - categorical_accuracy: 0.1250 - val_loss: 1.5129 - val_categorical_accuracy: 0.1905
# Epoch 109/1000
# 48/48 [==============================] - 0s - loss: 1.6609 - categorical_accuracy: 0.1667 - val_loss: 1.5065 - val_categorical_accuracy: 0.1905
# Epoch 110/1000
# 48/48 [==============================] - 0s - loss: 1.7329 - categorical_accuracy: 0.0625 - val_loss: 1.5106 - val_categorical_accuracy: 0.1429
# Epoch 111/1000
# 48/48 [==============================] - 0s - loss: 1.7032 - categorical_accuracy: 0.1458 - val_loss: 1.5075 - val_categorical_accuracy: 0.1905
# Epoch 112/1000
# 48/48 [==============================] - 0s - loss: 1.7193 - categorical_accuracy: 0.1042 - val_loss: 1.5059 - val_categorical_accuracy: 0.1429
# Epoch 113/1000
# 48/48 [==============================] - 0s - loss: 1.6828 - categorical_accuracy: 0.1042 - val_loss: 1.5048 - val_categorical_accuracy: 0.1429
# Epoch 114/1000
# 48/48 [==============================] - 0s - loss: 1.7212 - categorical_accuracy: 0.1042 - val_loss: 1.4899 - val_categorical_accuracy: 0.1905
# Epoch 115/1000
# 48/48 [==============================] - 0s - loss: 1.6325 - categorical_accuracy: 0.1250 - val_loss: 1.5235 - val_categorical_accuracy: 0.0000e+00
# Epoch 116/1000
# 48/48 [==============================] - 0s - loss: 1.7013 - categorical_accuracy: 0.1875 - val_loss: 1.4748 - val_categorical_accuracy: 0.1429
# Epoch 117/1000
# 48/48 [==============================] - 0s - loss: 1.6960 - categorical_accuracy: 0.0833 - val_loss: 1.4659 - val_categorical_accuracy: 0.1905
# Epoch 118/1000
# 48/48 [==============================] - 0s - loss: 1.7468 - categorical_accuracy: 0.1042 - val_loss: 1.5060 - val_categorical_accuracy: 0.0000e+00
# Epoch 119/1000
# 48/48 [==============================] - 0s - loss: 1.7056 - categorical_accuracy: 0.1250 - val_loss: 1.5041 - val_categorical_accuracy: 0.1429
# Epoch 120/1000
# 48/48 [==============================] - 0s - loss: 1.6879 - categorical_accuracy: 0.0833 - val_loss: 1.5208 - val_categorical_accuracy: 0.1429
# Epoch 121/1000
# 48/48 [==============================] - 0s - loss: 1.7305 - categorical_accuracy: 0.1250 - val_loss: 1.5090 - val_categorical_accuracy: 0.1429
# Epoch 122/1000
# 48/48 [==============================] - 0s - loss: 1.7878 - categorical_accuracy: 0.1042 - val_loss: 1.4961 - val_categorical_accuracy: 0.1905
# Epoch 123/1000
# 48/48 [==============================] - 0s - loss: 1.6896 - categorical_accuracy: 0.0625 - val_loss: 1.4943 - val_categorical_accuracy: 0.1429
# Epoch 124/1000
# 48/48 [==============================] - 0s - loss: 1.6465 - categorical_accuracy: 0.1458 - val_loss: 1.4961 - val_categorical_accuracy: 0.1905
# Epoch 125/1000
# 48/48 [==============================] - 0s - loss: 1.6965 - categorical_accuracy: 0.0625 - val_loss: 1.4990 - val_categorical_accuracy: 0.1429
# Epoch 126/1000
# 48/48 [==============================] - 0s - loss: 1.7138 - categorical_accuracy: 0.1250 - val_loss: 1.5053 - val_categorical_accuracy: 0.1429
# Epoch 127/1000
# 48/48 [==============================] - 0s - loss: 1.7067 - categorical_accuracy: 0.1042 - val_loss: 1.5025 - val_categorical_accuracy: 0.1905
# Epoch 128/1000
# 48/48 [==============================] - 0s - loss: 1.6944 - categorical_accuracy: 0.1042 - val_loss: 1.5011 - val_categorical_accuracy: 0.1905
# Epoch 129/1000
# 48/48 [==============================] - 0s - loss: 1.6643 - categorical_accuracy: 0.0833 - val_loss: 1.5081 - val_categorical_accuracy: 0.0476
# Epoch 130/1000
# 48/48 [==============================] - 0s - loss: 1.6718 - categorical_accuracy: 0.1250 - val_loss: 1.4816 - val_categorical_accuracy: 0.1429
# Epoch 131/1000
# 48/48 [==============================] - 0s - loss: 1.6518 - categorical_accuracy: 0.1250 - val_loss: 1.4847 - val_categorical_accuracy: 0.1429
# Epoch 132/1000
# 48/48 [==============================] - 0s - loss: 1.6707 - categorical_accuracy: 0.1042 - val_loss: 1.4829 - val_categorical_accuracy: 0.1429
# Epoch 133/1000
# 48/48 [==============================] - 0s - loss: 1.6675 - categorical_accuracy: 0.1250 - val_loss: 1.4851 - val_categorical_accuracy: 0.1429
# Epoch 134/1000
# 48/48 [==============================] - 0s - loss: 1.6726 - categorical_accuracy: 0.0833 - val_loss: 1.4871 - val_categorical_accuracy: 0.1429
# Epoch 135/1000
# 48/48 [==============================] - 0s - loss: 1.6860 - categorical_accuracy: 0.1250 - val_loss: 1.4859 - val_categorical_accuracy: 0.1429
# Epoch 136/1000
# 48/48 [==============================] - 0s - loss: 1.7053 - categorical_accuracy: 0.0833 - val_loss: 1.4816 - val_categorical_accuracy: 0.1429
# Epoch 137/1000
# 48/48 [==============================] - 0s - loss: 1.6620 - categorical_accuracy: 0.1250 - val_loss: 1.4788 - val_categorical_accuracy: 0.1429
# Epoch 138/1000
# 48/48 [==============================] - 0s - loss: 1.6120 - categorical_accuracy: 0.1042 - val_loss: 1.4782 - val_categorical_accuracy: 0.1905
# Epoch 139/1000
# 48/48 [==============================] - 0s - loss: 1.6883 - categorical_accuracy: 0.0417 - val_loss: 1.4937 - val_categorical_accuracy: 0.0952
# Epoch 140/1000
# 48/48 [==============================] - 0s - loss: 1.6615 - categorical_accuracy: 0.1250 - val_loss: 1.4756 - val_categorical_accuracy: 0.1429
# Epoch 141/1000
# 48/48 [==============================] - 0s - loss: 1.6561 - categorical_accuracy: 0.1042 - val_loss: 1.4727 - val_categorical_accuracy: 0.1905
# Epoch 142/1000
# 48/48 [==============================] - 0s - loss: 1.6736 - categorical_accuracy: 0.1250 - val_loss: 1.4922 - val_categorical_accuracy: 0.0952
# Epoch 143/1000
# 48/48 [==============================] - 0s - loss: 1.6574 - categorical_accuracy: 0.1250 - val_loss: 1.4717 - val_categorical_accuracy: 0.1429
# Epoch 144/1000
# 48/48 [==============================] - 0s - loss: 1.6660 - categorical_accuracy: 0.0625 - val_loss: 1.4809 - val_categorical_accuracy: 0.0952
# Epoch 145/1000
# 48/48 [==============================] - 0s - loss: 1.6760 - categorical_accuracy: 0.0833 - val_loss: 1.4689 - val_categorical_accuracy: 0.1905
# Epoch 146/1000
# 48/48 [==============================] - 0s - loss: 1.6552 - categorical_accuracy: 0.1042 - val_loss: 1.4696 - val_categorical_accuracy: 0.1429
# Epoch 147/1000
# 48/48 [==============================] - 0s - loss: 1.6545 - categorical_accuracy: 0.1250 - val_loss: 1.4732 - val_categorical_accuracy: 0.1429
# Epoch 148/1000
# 48/48 [==============================] - 0s - loss: 1.6617 - categorical_accuracy: 0.1667 - val_loss: 1.4708 - val_categorical_accuracy: 0.1905
# Epoch 149/1000
# 48/48 [==============================] - 0s - loss: 1.6560 - categorical_accuracy: 0.1250 - val_loss: 1.4844 - val_categorical_accuracy: 0.0952
# Epoch 150/1000
# 48/48 [==============================] - 0s - loss: 1.6668 - categorical_accuracy: 0.1042 - val_loss: 1.4688 - val_categorical_accuracy: 0.1905
# Epoch 151/1000
# 48/48 [==============================] - 0s - loss: 1.6093 - categorical_accuracy: 0.1250 - val_loss: 1.4654 - val_categorical_accuracy: 0.1429
# Epoch 152/1000
# 48/48 [==============================] - 0s - loss: 1.6449 - categorical_accuracy: 0.1042 - val_loss: 1.4779 - val_categorical_accuracy: 0.0476
# Epoch 153/1000
# 48/48 [==============================] - 0s - loss: 1.6603 - categorical_accuracy: 0.1042 - val_loss: 1.4696 - val_categorical_accuracy: 0.1905
# Epoch 154/1000
# 48/48 [==============================] - 0s - loss: 1.6601 - categorical_accuracy: 0.1250 - val_loss: 1.4671 - val_categorical_accuracy: 0.1905
# Epoch 155/1000
# 48/48 [==============================] - 0s - loss: 1.6706 - categorical_accuracy: 0.1667 - val_loss: 1.4803 - val_categorical_accuracy: 0.0476
# Epoch 156/1000
# 48/48 [==============================] - 0s - loss: 1.6672 - categorical_accuracy: 0.1250 - val_loss: 1.4502 - val_categorical_accuracy: 0.1429
# Epoch 157/1000
# 48/48 [==============================] - 0s - loss: 1.6517 - categorical_accuracy: 0.0833 - val_loss: 1.4610 - val_categorical_accuracy: 0.1905
# Epoch 158/1000
# 48/48 [==============================] - 0s - loss: 1.6711 - categorical_accuracy: 0.1042 - val_loss: 1.4894 - val_categorical_accuracy: 0.0952
# Epoch 159/1000
# 48/48 [==============================] - 0s - loss: 1.6490 - categorical_accuracy: 0.1458 - val_loss: 1.4772 - val_categorical_accuracy: 0.1429
# Epoch 160/1000
# 48/48 [==============================] - 0s - loss: 1.6413 - categorical_accuracy: 0.1042 - val_loss: 1.4767 - val_categorical_accuracy: 0.1429
# Epoch 161/1000
# 48/48 [==============================] - 0s - loss: 1.6094 - categorical_accuracy: 0.1458 - val_loss: 1.4715 - val_categorical_accuracy: 0.1429
# Epoch 162/1000
# 48/48 [==============================] - 0s - loss: 1.6456 - categorical_accuracy: 0.1042 - val_loss: 1.4544 - val_categorical_accuracy: 0.1905
# Epoch 163/1000
# 48/48 [==============================] - 0s - loss: 1.6371 - categorical_accuracy: 0.0833 - val_loss: 1.4506 - val_categorical_accuracy: 0.1429
# Epoch 164/1000
# 48/48 [==============================] - 0s - loss: 1.6606 - categorical_accuracy: 0.1042 - val_loss: 1.4752 - val_categorical_accuracy: 0.0952
# Epoch 165/1000
# 48/48 [==============================] - 0s - loss: 1.6462 - categorical_accuracy: 0.1458 - val_loss: 1.4766 - val_categorical_accuracy: 0.1429
# Epoch 166/1000
# 48/48 [==============================] - 0s - loss: 1.6592 - categorical_accuracy: 0.1458 - val_loss: 1.4781 - val_categorical_accuracy: 0.1905
# Epoch 167/1000
# 48/48 [==============================] - 0s - loss: 1.6578 - categorical_accuracy: 0.0833 - val_loss: 1.4768 - val_categorical_accuracy: 0.1429
# Epoch 168/1000
# 48/48 [==============================] - 0s - loss: 1.6367 - categorical_accuracy: 0.1458 - val_loss: 1.4651 - val_categorical_accuracy: 0.1429
# Epoch 169/1000
# 48/48 [==============================] - 0s - loss: 1.6589 - categorical_accuracy: 0.0833 - val_loss: 1.4597 - val_categorical_accuracy: 0.1429
# Epoch 170/1000
# 48/48 [==============================] - 0s - loss: 1.6081 - categorical_accuracy: 0.1458 - val_loss: 1.4649 - val_categorical_accuracy: 0.1429
# Epoch 171/1000
# 48/48 [==============================] - 0s - loss: 1.6490 - categorical_accuracy: 0.1458 - val_loss: 1.4607 - val_categorical_accuracy: 0.1905
# Epoch 172/1000
# 48/48 [==============================] - 0s - loss: 1.6434 - categorical_accuracy: 0.1458 - val_loss: 1.4642 - val_categorical_accuracy: 0.1905
# Epoch 173/1000
# 48/48 [==============================] - 0s - loss: 1.6309 - categorical_accuracy: 0.1667 - val_loss: 1.4748 - val_categorical_accuracy: 0.0952
# Epoch 174/1000
# 48/48 [==============================] - 0s - loss: 1.6130 - categorical_accuracy: 0.1458 - val_loss: 1.4597 - val_categorical_accuracy: 0.1905
# Epoch 175/1000
# 48/48 [==============================] - 0s - loss: 1.6322 - categorical_accuracy: 0.1042 - val_loss: 1.4591 - val_categorical_accuracy: 0.1905
# Epoch 176/1000
# 48/48 [==============================] - 0s - loss: 1.6325 - categorical_accuracy: 0.1458 - val_loss: 1.4576 - val_categorical_accuracy: 0.1429
# Epoch 177/1000
# 48/48 [==============================] - 0s - loss: 1.6663 - categorical_accuracy: 0.1042 - val_loss: 1.4565 - val_categorical_accuracy: 0.1905
# Epoch 178/1000
# 48/48 [==============================] - 0s - loss: 1.6306 - categorical_accuracy: 0.1250 - val_loss: 1.4492 - val_categorical_accuracy: 0.1905
# Epoch 179/1000
# 48/48 [==============================] - 0s - loss: 1.6371 - categorical_accuracy: 0.0833 - val_loss: 1.4643 - val_categorical_accuracy: 0.0952
# Epoch 180/1000
# 48/48 [==============================] - 0s - loss: 1.6330 - categorical_accuracy: 0.1458 - val_loss: 1.4480 - val_categorical_accuracy: 0.1905
# Epoch 181/1000
# 48/48 [==============================] - 0s - loss: 1.6311 - categorical_accuracy: 0.1458 - val_loss: 1.4520 - val_categorical_accuracy: 0.1429
# Epoch 182/1000
# 48/48 [==============================] - 0s - loss: 1.5734 - categorical_accuracy: 0.1042 - val_loss: 1.4503 - val_categorical_accuracy: 0.1429
# Epoch 183/1000
# 48/48 [==============================] - 0s - loss: 1.6161 - categorical_accuracy: 0.1458 - val_loss: 1.4698 - val_categorical_accuracy: 0.0476
# Epoch 184/1000
# 48/48 [==============================] - 0s - loss: 1.6132 - categorical_accuracy: 0.1875 - val_loss: 1.4530 - val_categorical_accuracy: 0.1905
# Epoch 185/1000
# 48/48 [==============================] - 0s - loss: 1.6407 - categorical_accuracy: 0.1042 - val_loss: 1.4612 - val_categorical_accuracy: 0.1429
# Epoch 186/1000
# 48/48 [==============================] - 0s - loss: 1.6115 - categorical_accuracy: 0.0625 - val_loss: 1.4764 - val_categorical_accuracy: 0.0952
# Epoch 187/1000
# 48/48 [==============================] - 0s - loss: 1.5511 - categorical_accuracy: 0.1250 - val_loss: 1.4570 - val_categorical_accuracy: 0.1905
# Epoch 188/1000
# 48/48 [==============================] - 0s - loss: 1.6144 - categorical_accuracy: 0.1042 - val_loss: 1.4683 - val_categorical_accuracy: 0.0476
# Epoch 189/1000
# 48/48 [==============================] - 0s - loss: 1.6381 - categorical_accuracy: 0.1250 - val_loss: 1.4544 - val_categorical_accuracy: 0.1429
# Epoch 190/1000
# 48/48 [==============================] - 0s - loss: 1.6102 - categorical_accuracy: 0.1042 - val_loss: 1.4280 - val_categorical_accuracy: 0.1905
# Epoch 191/1000
# 48/48 [==============================] - 0s - loss: 1.7077 - categorical_accuracy: 0.1042 - val_loss: 1.3889 - val_categorical_accuracy: 0.1429
# Epoch 192/1000
# 48/48 [==============================] - 0s - loss: 1.7049 - categorical_accuracy: 0.1042 - val_loss: 1.3978 - val_categorical_accuracy: 0.0476
# Epoch 193/1000
# 48/48 [==============================] - 0s - loss: 1.5396 - categorical_accuracy: 0.1250 - val_loss: 1.4444 - val_categorical_accuracy: 0.1905
# Epoch 194/1000
# 48/48 [==============================] - 0s - loss: 1.5812 - categorical_accuracy: 0.1458 - val_loss: 1.4441 - val_categorical_accuracy: 0.1429
# Epoch 195/1000
# 48/48 [==============================] - 0s - loss: 1.5488 - categorical_accuracy: 0.1667 - val_loss: 1.4587 - val_categorical_accuracy: 0.1905
# Epoch 196/1000
# 48/48 [==============================] - 0s - loss: 1.6022 - categorical_accuracy: 0.1458 - val_loss: 1.4676 - val_categorical_accuracy: 0.1429
# Epoch 197/1000
# 48/48 [==============================] - 0s - loss: 1.5921 - categorical_accuracy: 0.1458 - val_loss: 1.4620 - val_categorical_accuracy: 0.1429
# Epoch 198/1000
# 48/48 [==============================] - 0s - loss: 1.5762 - categorical_accuracy: 0.1042 - val_loss: 1.4457 - val_categorical_accuracy: 0.1429
# Epoch 199/1000
# 48/48 [==============================] - 0s - loss: 1.6924 - categorical_accuracy: 0.0625 - val_loss: 1.4343 - val_categorical_accuracy: 0.1905
# Epoch 200/1000
# 48/48 [==============================] - 0s - loss: 1.5222 - categorical_accuracy: 0.0833 - val_loss: 1.4296 - val_categorical_accuracy: 0.1429
# Epoch 201/1000
# 48/48 [==============================] - 0s - loss: 1.5626 - categorical_accuracy: 0.1250 - val_loss: 1.3956 - val_categorical_accuracy: 0.0952
# Epoch 202/1000
# 48/48 [==============================] - 0s - loss: 1.4926 - categorical_accuracy: 0.0625 - val_loss: 1.2227 - val_categorical_accuracy: 0.0952
# Epoch 203/1000
# 48/48 [==============================] - 0s - loss: 1.3118 - categorical_accuracy: 0.1458 - val_loss: 0.9945 - val_categorical_accuracy: 0.1429
# Epoch 204/1000
# 48/48 [==============================] - 0s - loss: 1.2242 - categorical_accuracy: 0.1250 - val_loss: 1.0210 - val_categorical_accuracy: 0.1905
# Epoch 205/1000
# 48/48 [==============================] - 0s - loss: 1.3026 - categorical_accuracy: 0.1458 - val_loss: 1.3050 - val_categorical_accuracy: 0.1429
# Epoch 206/1000
# 48/48 [==============================] - 0s - loss: 1.2914 - categorical_accuracy: 0.1042 - val_loss: 0.9330 - val_categorical_accuracy: 0.0476
# Epoch 207/1000
# 48/48 [==============================] - 0s - loss: 1.3069 - categorical_accuracy: 0.1458 - val_loss: 0.9509 - val_categorical_accuracy: 0.0952
# Epoch 208/1000
# 48/48 [==============================] - 0s - loss: 1.1474 - categorical_accuracy: 0.1042 - val_loss: 0.9901 - val_categorical_accuracy: 0.2381
# Epoch 209/1000
# 48/48 [==============================] - 0s - loss: 1.1768 - categorical_accuracy: 0.1875 - val_loss: 0.8200 - val_categorical_accuracy: 0.2381
# Epoch 210/1000
# 48/48 [==============================] - 0s - loss: 0.9743 - categorical_accuracy: 0.1667 - val_loss: 0.7869 - val_categorical_accuracy: 0.0476
# Epoch 211/1000
# 48/48 [==============================] - 0s - loss: 1.1168 - categorical_accuracy: 0.0833 - val_loss: 0.6629 - val_categorical_accuracy: 0.0952
# Epoch 212/1000
# 48/48 [==============================] - 0s - loss: 1.0265 - categorical_accuracy: 0.1458 - val_loss: 0.6764 - val_categorical_accuracy: 0.2381
# Epoch 213/1000
# 48/48 [==============================] - 0s - loss: 0.9748 - categorical_accuracy: 0.1667 - val_loss: 0.7514 - val_categorical_accuracy: 0.2381
# Epoch 214/1000
# 48/48 [==============================] - 0s - loss: 0.6654 - categorical_accuracy: 0.2708 - val_loss: 0.5422 - val_categorical_accuracy: 0.0952
# Epoch 215/1000
# 48/48 [==============================] - 0s - loss: 0.7584 - categorical_accuracy: 0.1042 - val_loss: 0.5301 - val_categorical_accuracy: 0.1905
# Epoch 216/1000
# 48/48 [==============================] - 0s - loss: 0.7436 - categorical_accuracy: 0.2083 - val_loss: 0.5431 - val_categorical_accuracy: 0.1905
# Epoch 217/1000
# 48/48 [==============================] - 0s - loss: 0.7032 - categorical_accuracy: 0.2500 - val_loss: 0.5672 - val_categorical_accuracy: 0.1429
# Epoch 218/1000
# 48/48 [==============================] - 0s - loss: 0.6508 - categorical_accuracy: 0.0833 - val_loss: 0.5630 - val_categorical_accuracy: 0.1905
# Epoch 219/1000
# 48/48 [==============================] - 0s - loss: 0.4279 - categorical_accuracy: 0.2500 - val_loss: 0.5248 - val_categorical_accuracy: 0.0952
# Epoch 220/1000
# 48/48 [==============================] - 0s - loss: 0.5169 - categorical_accuracy: 0.2083 - val_loss: 0.5289 - val_categorical_accuracy: 0.0000e+00
# Epoch 221/1000
# 48/48 [==============================] - 0s - loss: 0.4440 - categorical_accuracy: 0.2292 - val_loss: 0.5207 - val_categorical_accuracy: 0.0476
# Epoch 222/1000
# 48/48 [==============================] - 0s - loss: 0.4602 - categorical_accuracy: 0.1250 - val_loss: 0.5197 - val_categorical_accuracy: 0.0476
# Epoch 223/1000
# 48/48 [==============================] - 0s - loss: 0.4172 - categorical_accuracy: 0.3125 - val_loss: 0.5113 - val_categorical_accuracy: 0.0952
# Epoch 224/1000
# 48/48 [==============================] - 0s - loss: 0.4087 - categorical_accuracy: 0.3125 - val_loss: 0.5052 - val_categorical_accuracy: 0.1905
# Epoch 225/1000
# 48/48 [==============================] - 0s - loss: 0.4355 - categorical_accuracy: 0.1875 - val_loss: 0.5064 - val_categorical_accuracy: 0.1429
# Epoch 226/1000
# 48/48 [==============================] - 0s - loss: 0.4283 - categorical_accuracy: 0.3333 - val_loss: 0.5042 - val_categorical_accuracy: 0.2381
# Epoch 227/1000
# 48/48 [==============================] - 0s - loss: 0.4210 - categorical_accuracy: 0.2708 - val_loss: 0.5081 - val_categorical_accuracy: 0.2381
# Epoch 228/1000
# 48/48 [==============================] - 0s - loss: 0.3888 - categorical_accuracy: 0.3333 - val_loss: 0.5286 - val_categorical_accuracy: 0.1905
# Epoch 229/1000
# 48/48 [==============================] - 0s - loss: 0.4057 - categorical_accuracy: 0.3333 - val_loss: 0.5221 - val_categorical_accuracy: 0.1905
# Epoch 230/1000
# 48/48 [==============================] - 0s - loss: 0.3989 - categorical_accuracy: 0.2917 - val_loss: 0.5198 - val_categorical_accuracy: 0.1429
# Epoch 231/1000
# 48/48 [==============================] - 0s - loss: 0.4104 - categorical_accuracy: 0.3333 - val_loss: 0.5149 - val_categorical_accuracy: 0.1429
# Epoch 232/1000
# 48/48 [==============================] - 0s - loss: 0.3963 - categorical_accuracy: 0.2917 - val_loss: 0.5073 - val_categorical_accuracy: 0.1429
# Epoch 233/1000
# 48/48 [==============================] - 0s - loss: 0.4034 - categorical_accuracy: 0.2708 - val_loss: 0.5086 - val_categorical_accuracy: 0.1905
# Epoch 234/1000
# 48/48 [==============================] - 0s - loss: 0.3990 - categorical_accuracy: 0.3542 - val_loss: 0.5127 - val_categorical_accuracy: 0.1905
# Epoch 235/1000
# 48/48 [==============================] - 0s - loss: 0.4056 - categorical_accuracy: 0.3333 - val_loss: 0.5170 - val_categorical_accuracy: 0.1429
# Epoch 236/1000
# 48/48 [==============================] - 0s - loss: 0.3842 - categorical_accuracy: 0.3333 - val_loss: 0.5235 - val_categorical_accuracy: 0.1905
# Epoch 237/1000
# 48/48 [==============================] - 0s - loss: 0.3934 - categorical_accuracy: 0.2500 - val_loss: 0.5204 - val_categorical_accuracy: 0.0952
# Epoch 238/1000
# 48/48 [==============================] - 0s - loss: 0.3870 - categorical_accuracy: 0.3542 - val_loss: 0.5148 - val_categorical_accuracy: 0.0952
# Epoch 239/1000
# 48/48 [==============================] - 0s - loss: 0.3797 - categorical_accuracy: 0.3750 - val_loss: 0.5214 - val_categorical_accuracy: 0.0476
# Epoch 240/1000
# 48/48 [==============================] - 0s - loss: 0.3934 - categorical_accuracy: 0.3125 - val_loss: 0.5270 - val_categorical_accuracy: 0.0952
# Epoch 241/1000
# 48/48 [==============================] - 0s - loss: 0.3830 - categorical_accuracy: 0.2917 - val_loss: 0.5159 - val_categorical_accuracy: 0.1429
# Epoch 242/1000
# 48/48 [==============================] - 0s - loss: 0.3739 - categorical_accuracy: 0.3958 - val_loss: 0.5051 - val_categorical_accuracy: 0.0952
# Epoch 243/1000
# 48/48 [==============================] - 0s - loss: 0.3812 - categorical_accuracy: 0.3333 - val_loss: 0.5034 - val_categorical_accuracy: 0.1905
# Epoch 244/1000
# 48/48 [==============================] - 0s - loss: 0.3623 - categorical_accuracy: 0.4375 - val_loss: 0.5164 - val_categorical_accuracy: 0.2381
# Epoch 245/1000
# 48/48 [==============================] - 0s - loss: 0.3796 - categorical_accuracy: 0.2708 - val_loss: 0.4996 - val_categorical_accuracy: 0.1429
# Epoch 246/1000
# 48/48 [==============================] - 0s - loss: 0.3512 - categorical_accuracy: 0.4167 - val_loss: 0.5027 - val_categorical_accuracy: 0.0952
# Epoch 247/1000
# 48/48 [==============================] - 0s - loss: 0.3816 - categorical_accuracy: 0.3333 - val_loss: 0.5016 - val_categorical_accuracy: 0.0952
# Epoch 248/1000
# 48/48 [==============================] - 0s - loss: 0.3459 - categorical_accuracy: 0.3958 - val_loss: 0.5025 - val_categorical_accuracy: 0.2381
# Epoch 249/1000
# 48/48 [==============================] - 0s - loss: 0.3441 - categorical_accuracy: 0.4167 - val_loss: 0.5024 - val_categorical_accuracy: 0.2381
# Epoch 250/1000
# 48/48 [==============================] - 0s - loss: 0.3635 - categorical_accuracy: 0.3750 - val_loss: 0.4990 - val_categorical_accuracy: 0.2381
# Epoch 251/1000
# 48/48 [==============================] - 0s - loss: 0.3407 - categorical_accuracy: 0.4167 - val_loss: 0.5044 - val_categorical_accuracy: 0.0952
# Epoch 252/1000
# 48/48 [==============================] - 0s - loss: 0.3617 - categorical_accuracy: 0.4583 - val_loss: 0.5091 - val_categorical_accuracy: 0.0952
# Epoch 253/1000
# 48/48 [==============================] - 0s - loss: 0.3385 - categorical_accuracy: 0.4167 - val_loss: 0.5148 - val_categorical_accuracy: 0.0952
# Epoch 254/1000
# 48/48 [==============================] - 0s - loss: 0.3410 - categorical_accuracy: 0.4583 - val_loss: 0.5279 - val_categorical_accuracy: 0.1905
# Epoch 255/1000
# 48/48 [==============================] - 0s - loss: 0.3454 - categorical_accuracy: 0.4792 - val_loss: 0.5275 - val_categorical_accuracy: 0.2857
# Epoch 256/1000
# 48/48 [==============================] - 0s - loss: 0.3624 - categorical_accuracy: 0.4792 - val_loss: 0.5206 - val_categorical_accuracy: 0.1429
# Epoch 257/1000
# 48/48 [==============================] - 0s - loss: 0.3261 - categorical_accuracy: 0.5417 - val_loss: 0.5097 - val_categorical_accuracy: 0.0952
# Epoch 258/1000
# 48/48 [==============================] - 0s - loss: 0.3684 - categorical_accuracy: 0.4375 - val_loss: 0.5202 - val_categorical_accuracy: 0.1429
# Epoch 259/1000
# 48/48 [==============================] - 0s - loss: 0.3425 - categorical_accuracy: 0.4167 - val_loss: 0.5082 - val_categorical_accuracy: 0.1429
# Epoch 260/1000
# 48/48 [==============================] - 0s - loss: 0.3323 - categorical_accuracy: 0.5000 - val_loss: 0.5129 - val_categorical_accuracy: 0.1429
# Epoch 261/1000
# 48/48 [==============================] - 0s - loss: 0.3432 - categorical_accuracy: 0.4792 - val_loss: 0.5130 - val_categorical_accuracy: 0.1429
# Epoch 262/1000
# 48/48 [==============================] - 0s - loss: 0.3327 - categorical_accuracy: 0.3750 - val_loss: 0.5063 - val_categorical_accuracy: 0.1429
# Epoch 263/1000
# 48/48 [==============================] - 0s - loss: 0.3476 - categorical_accuracy: 0.3958 - val_loss: 0.4996 - val_categorical_accuracy: 0.1905
# Epoch 264/1000
# 48/48 [==============================] - 0s - loss: 0.3271 - categorical_accuracy: 0.5208 - val_loss: 0.5213 - val_categorical_accuracy: 0.1905
# Epoch 265/1000
# 48/48 [==============================] - 0s - loss: 0.3287 - categorical_accuracy: 0.4792 - val_loss: 0.5192 - val_categorical_accuracy: 0.2381
# Epoch 266/1000
# 48/48 [==============================] - 0s - loss: 0.3258 - categorical_accuracy: 0.5000 - val_loss: 0.5005 - val_categorical_accuracy: 0.1429
# Epoch 267/1000
# 48/48 [==============================] - 0s - loss: 0.3294 - categorical_accuracy: 0.5208 - val_loss: 0.5138 - val_categorical_accuracy: 0.1905
# Epoch 268/1000
# 48/48 [==============================] - 0s - loss: 0.3339 - categorical_accuracy: 0.5000 - val_loss: 0.5126 - val_categorical_accuracy: 0.1905
# Epoch 269/1000
# 48/48 [==============================] - 0s - loss: 0.3273 - categorical_accuracy: 0.5000 - val_loss: 0.5161 - val_categorical_accuracy: 0.2381
# Epoch 270/1000
# 48/48 [==============================] - 0s - loss: 0.3186 - categorical_accuracy: 0.5000 - val_loss: 0.5029 - val_categorical_accuracy: 0.1905
# Epoch 271/1000
# 48/48 [==============================] - 0s - loss: 0.3210 - categorical_accuracy: 0.5208 - val_loss: 0.4940 - val_categorical_accuracy: 0.1429
# Epoch 272/1000
# 48/48 [==============================] - 0s - loss: 0.3015 - categorical_accuracy: 0.5833 - val_loss: 0.4995 - val_categorical_accuracy: 0.1905
# Epoch 273/1000
# 48/48 [==============================] - 0s - loss: 0.2982 - categorical_accuracy: 0.5417 - val_loss: 0.5024 - val_categorical_accuracy: 0.2381
# Epoch 274/1000
# 48/48 [==============================] - 0s - loss: 0.3079 - categorical_accuracy: 0.5625 - val_loss: 0.5081 - val_categorical_accuracy: 0.2857
# Epoch 275/1000
# 48/48 [==============================] - 0s - loss: 0.3028 - categorical_accuracy: 0.5625 - val_loss: 0.5047 - val_categorical_accuracy: 0.2857
# Epoch 276/1000
# 48/48 [==============================] - 0s - loss: 0.2968 - categorical_accuracy: 0.6042 - val_loss: 0.5055 - val_categorical_accuracy: 0.2381
# Epoch 277/1000
# 48/48 [==============================] - 0s - loss: 0.3029 - categorical_accuracy: 0.5833 - val_loss: 0.5012 - val_categorical_accuracy: 0.2381
# Epoch 278/1000
# 48/48 [==============================] - 0s - loss: 0.2973 - categorical_accuracy: 0.6250 - val_loss: 0.5133 - val_categorical_accuracy: 0.2857
# Epoch 279/1000
# 48/48 [==============================] - 0s - loss: 0.3191 - categorical_accuracy: 0.5208 - val_loss: 0.5206 - val_categorical_accuracy: 0.2857
# Epoch 280/1000
# 48/48 [==============================] - 0s - loss: 0.3159 - categorical_accuracy: 0.4792 - val_loss: 0.5209 - val_categorical_accuracy: 0.2857
# Epoch 281/1000
# 48/48 [==============================] - 0s - loss: 0.3365 - categorical_accuracy: 0.5000 - val_loss: 0.5048 - val_categorical_accuracy: 0.2381
# Epoch 282/1000
# 48/48 [==============================] - 0s - loss: 0.2898 - categorical_accuracy: 0.5833 - val_loss: 0.4910 - val_categorical_accuracy: 0.2381
# Epoch 283/1000
# 48/48 [==============================] - 0s - loss: 0.3079 - categorical_accuracy: 0.5000 - val_loss: 0.4990 - val_categorical_accuracy: 0.2381
# Epoch 284/1000
# 48/48 [==============================] - 0s - loss: 0.2872 - categorical_accuracy: 0.5833 - val_loss: 0.5022 - val_categorical_accuracy: 0.2381
# Epoch 285/1000
# 48/48 [==============================] - 0s - loss: 0.3181 - categorical_accuracy: 0.5208 - val_loss: 0.5218 - val_categorical_accuracy: 0.1429
# Epoch 286/1000
# 48/48 [==============================] - 0s - loss: 0.2973 - categorical_accuracy: 0.5625 - val_loss: 0.5218 - val_categorical_accuracy: 0.2857
# Epoch 287/1000
# 48/48 [==============================] - 0s - loss: 0.2951 - categorical_accuracy: 0.5208 - val_loss: 0.5356 - val_categorical_accuracy: 0.2381
# Epoch 288/1000
# 48/48 [==============================] - 0s - loss: 0.3261 - categorical_accuracy: 0.5000 - val_loss: 0.5430 - val_categorical_accuracy: 0.2381
# Epoch 289/1000
# 48/48 [==============================] - 0s - loss: 0.3160 - categorical_accuracy: 0.5208 - val_loss: 0.5225 - val_categorical_accuracy: 0.2857
# Epoch 290/1000
# 48/48 [==============================] - 0s - loss: 0.2969 - categorical_accuracy: 0.6042 - val_loss: 0.5176 - val_categorical_accuracy: 0.2381
# Epoch 291/1000
# 48/48 [==============================] - 0s - loss: 0.3128 - categorical_accuracy: 0.5208 - val_loss: 0.5033 - val_categorical_accuracy: 0.2857
# Epoch 292/1000
# 48/48 [==============================] - 0s - loss: 0.2920 - categorical_accuracy: 0.5625 - val_loss: 0.4982 - val_categorical_accuracy: 0.3333
# Epoch 293/1000
# 48/48 [==============================] - 0s - loss: 0.2882 - categorical_accuracy: 0.6250 - val_loss: 0.5109 - val_categorical_accuracy: 0.2857
# Epoch 294/1000
# 48/48 [==============================] - 0s - loss: 0.2840 - categorical_accuracy: 0.6875 - val_loss: 0.5198 - val_categorical_accuracy: 0.1905
# Epoch 295/1000
# 48/48 [==============================] - 0s - loss: 0.3178 - categorical_accuracy: 0.5625 - val_loss: 0.5198 - val_categorical_accuracy: 0.2857
# Epoch 296/1000
# 48/48 [==============================] - 0s - loss: 0.3181 - categorical_accuracy: 0.5833 - val_loss: 0.5216 - val_categorical_accuracy: 0.1429
# Epoch 297/1000
# 48/48 [==============================] - 0s - loss: 0.3119 - categorical_accuracy: 0.4583 - val_loss: 0.5242 - val_categorical_accuracy: 0.1429
# Epoch 298/1000
# 48/48 [==============================] - 0s - loss: 0.2988 - categorical_accuracy: 0.4792 - val_loss: 0.5019 - val_categorical_accuracy: 0.1905
# Epoch 299/1000
# 48/48 [==============================] - 0s - loss: 0.2788 - categorical_accuracy: 0.5625 - val_loss: 0.4945 - val_categorical_accuracy: 0.3333
# Epoch 300/1000
# 48/48 [==============================] - 0s - loss: 0.3036 - categorical_accuracy: 0.4792 - val_loss: 0.4883 - val_categorical_accuracy: 0.3333
# Epoch 301/1000
# 48/48 [==============================] - 0s - loss: 0.2814 - categorical_accuracy: 0.6042 - val_loss: 0.4834 - val_categorical_accuracy: 0.3333
# ...
# Epoch 902/1000
# 468/468 [==============================] - 0s - loss: 0.1110 - categorical_accuracy: 0.8504 - val_loss: 0.1021 - val_categorical_accuracy: 0.8806
# Epoch 903/1000
# 468/468 [==============================] - 0s - loss: 0.1075 - categorical_accuracy: 0.8526 - val_loss: 0.1063 - val_categorical_accuracy: 0.8657
# Epoch 904/1000
# 468/468 [==============================] - 0s - loss: 0.1499 - categorical_accuracy: 0.7692 - val_loss: 0.1341 - val_categorical_accuracy: 0.7960
# Epoch 905/1000
# 468/468 [==============================] - 0s - loss: 0.1091 - categorical_accuracy: 0.8462 - val_loss: 0.1143 - val_categorical_accuracy: 0.8408
# Epoch 906/1000
# 468/468 [==============================] - 0s - loss: 0.1104 - categorical_accuracy: 0.8526 - val_loss: 0.1201 - val_categorical_accuracy: 0.8557
# Epoch 907/1000
# 468/468 [==============================] - 0s - loss: 0.1183 - categorical_accuracy: 0.8098 - val_loss: 0.1386 - val_categorical_accuracy: 0.8259
# Epoch 908/1000
# 468/468 [==============================] - 0s - loss: 0.1148 - categorical_accuracy: 0.8248 - val_loss: 0.1112 - val_categorical_accuracy: 0.8706
# Epoch 909/1000
# 468/468 [==============================] - 0s - loss: 0.1156 - categorical_accuracy: 0.8376 - val_loss: 0.1271 - val_categorical_accuracy: 0.8557
# Epoch 910/1000
# 468/468 [==============================] - 0s - loss: 0.1523 - categorical_accuracy: 0.7650 - val_loss: 0.2648 - val_categorical_accuracy: 0.5672
# Epoch 911/1000
# 468/468 [==============================] - 0s - loss: 0.2394 - categorical_accuracy: 0.6132 - val_loss: 0.2288 - val_categorical_accuracy: 0.6418
# Epoch 912/1000
# 468/468 [==============================] - 0s - loss: 0.1712 - categorical_accuracy: 0.6987 - val_loss: 0.1561 - val_categorical_accuracy: 0.7512
# Epoch 913/1000
# 468/468 [==============================] - 0s - loss: 0.1697 - categorical_accuracy: 0.7073 - val_loss: 0.2626 - val_categorical_accuracy: 0.5871
# Epoch 914/1000
# 468/468 [==============================] - 0s - loss: 0.1908 - categorical_accuracy: 0.6667 - val_loss: 0.1929 - val_categorical_accuracy: 0.6866
# Epoch 915/1000
# 468/468 [==============================] - 0s - loss: 0.2208 - categorical_accuracy: 0.6047 - val_loss: 0.1968 - val_categorical_accuracy: 0.6269
# Epoch 916/1000
# 468/468 [==============================] - 0s - loss: 0.1796 - categorical_accuracy: 0.7201 - val_loss: 0.1498 - val_categorical_accuracy: 0.7711
# Epoch 917/1000
# 468/468 [==============================] - 0s - loss: 0.1721 - categorical_accuracy: 0.7115 - val_loss: 0.1854 - val_categorical_accuracy: 0.7313
# Epoch 918/1000
# 468/468 [==============================] - 0s - loss: 0.1566 - categorical_accuracy: 0.7521 - val_loss: 0.1429 - val_categorical_accuracy: 0.7861
# Epoch 919/1000
# 468/468 [==============================] - 0s - loss: 0.1772 - categorical_accuracy: 0.7158 - val_loss: 0.1534 - val_categorical_accuracy: 0.7761
# Epoch 920/1000
# 468/468 [==============================] - 0s - loss: 0.1677 - categorical_accuracy: 0.7201 - val_loss: 0.1929 - val_categorical_accuracy: 0.7313
# Epoch 921/1000
# 468/468 [==============================] - 0s - loss: 0.1755 - categorical_accuracy: 0.7201 - val_loss: 0.1524 - val_categorical_accuracy: 0.7363
# Epoch 922/1000
# 468/468 [==============================] - 0s - loss: 0.1712 - categorical_accuracy: 0.7201 - val_loss: 0.1797 - val_categorical_accuracy: 0.7065
# Epoch 923/1000
# 468/468 [==============================] - 0s - loss: 0.1739 - categorical_accuracy: 0.7286 - val_loss: 0.1549 - val_categorical_accuracy: 0.7413
# Epoch 924/1000
# 468/468 [==============================] - 0s - loss: 0.1771 - categorical_accuracy: 0.7222 - val_loss: 0.2033 - val_categorical_accuracy: 0.6418
# Epoch 925/1000
# 468/468 [==============================] - 0s - loss: 0.1908 - categorical_accuracy: 0.6624 - val_loss: 0.2223 - val_categorical_accuracy: 0.6418
# Epoch 926/1000
# 468/468 [==============================] - 0s - loss: 0.1494 - categorical_accuracy: 0.7585 - val_loss: 0.1458 - val_categorical_accuracy: 0.7612
# Epoch 927/1000
# 468/468 [==============================] - 0s - loss: 0.1593 - categorical_accuracy: 0.7372 - val_loss: 0.1837 - val_categorical_accuracy: 0.6965
# Epoch 928/1000
# 468/468 [==============================] - 0s - loss: 0.1703 - categorical_accuracy: 0.7201 - val_loss: 0.2344 - val_categorical_accuracy: 0.6318
# Epoch 929/1000
# 468/468 [==============================] - 0s - loss: 0.1814 - categorical_accuracy: 0.6795 - val_loss: 0.1631 - val_categorical_accuracy: 0.7363
# Epoch 930/1000
# 468/468 [==============================] - 0s - loss: 0.1599 - categorical_accuracy: 0.7308 - val_loss: 0.1584 - val_categorical_accuracy: 0.7910
# Epoch 931/1000
# 468/468 [==============================] - 0s - loss: 0.1867 - categorical_accuracy: 0.6880 - val_loss: 0.1952 - val_categorical_accuracy: 0.6667
# Epoch 932/1000
# 468/468 [==============================] - 0s - loss: 0.1835 - categorical_accuracy: 0.6795 - val_loss: 0.1602 - val_categorical_accuracy: 0.7512
# Epoch 933/1000
# 468/468 [==============================] - 0s - loss: 0.1665 - categorical_accuracy: 0.7500 - val_loss: 0.1462 - val_categorical_accuracy: 0.7711
# Epoch 934/1000
# 468/468 [==============================] - 0s - loss: 0.1858 - categorical_accuracy: 0.6774 - val_loss: 0.1835 - val_categorical_accuracy: 0.7114
# Epoch 935/1000
# 468/468 [==============================] - 0s - loss: 0.1800 - categorical_accuracy: 0.6816 - val_loss: 0.1844 - val_categorical_accuracy: 0.7164
# Epoch 936/1000
# 468/468 [==============================] - 0s - loss: 0.1867 - categorical_accuracy: 0.6923 - val_loss: 0.2017 - val_categorical_accuracy: 0.6368
# Epoch 937/1000
# 468/468 [==============================] - 0s - loss: 0.1631 - categorical_accuracy: 0.7222 - val_loss: 0.2136 - val_categorical_accuracy: 0.6766
# Epoch 938/1000
# 468/468 [==============================] - 0s - loss: 0.1546 - categorical_accuracy: 0.7436 - val_loss: 0.1498 - val_categorical_accuracy: 0.7711
# Epoch 939/1000
# 468/468 [==============================] - 0s - loss: 0.1654 - categorical_accuracy: 0.7286 - val_loss: 0.1787 - val_categorical_accuracy: 0.7313
# Epoch 940/1000
# 468/468 [==============================] - 0s - loss: 0.1622 - categorical_accuracy: 0.7436 - val_loss: 0.1702 - val_categorical_accuracy: 0.7413
# Epoch 941/1000
# 468/468 [==============================] - 0s - loss: 0.1512 - categorical_accuracy: 0.7650 - val_loss: 0.1420 - val_categorical_accuracy: 0.7811
# Epoch 942/1000
# 468/468 [==============================] - 0s - loss: 0.1592 - categorical_accuracy: 0.7244 - val_loss: 0.2066 - val_categorical_accuracy: 0.6766
# Epoch 943/1000
# 468/468 [==============================] - 0s - loss: 0.1617 - categorical_accuracy: 0.7265 - val_loss: 0.1449 - val_categorical_accuracy: 0.7910
# Epoch 944/1000
# 468/468 [==============================] - 0s - loss: 0.1721 - categorical_accuracy: 0.7137 - val_loss: 0.1477 - val_categorical_accuracy: 0.7761
# Epoch 945/1000
# 468/468 [==============================] - 0s - loss: 0.1736 - categorical_accuracy: 0.7073 - val_loss: 0.1658 - val_categorical_accuracy: 0.7463
# Epoch 946/1000
# 468/468 [==============================] - 0s - loss: 0.1661 - categorical_accuracy: 0.7137 - val_loss: 0.1706 - val_categorical_accuracy: 0.7363
# Epoch 947/1000
# 468/468 [==============================] - 0s - loss: 0.1707 - categorical_accuracy: 0.7179 - val_loss: 0.1645 - val_categorical_accuracy: 0.7512
# Epoch 948/1000
# 468/468 [==============================] - 0s - loss: 0.1566 - categorical_accuracy: 0.7500 - val_loss: 0.1588 - val_categorical_accuracy: 0.7512
# Epoch 949/1000
# 468/468 [==============================] - 0s - loss: 0.1590 - categorical_accuracy: 0.7244 - val_loss: 0.2062 - val_categorical_accuracy: 0.6766
# Epoch 950/1000
# 468/468 [==============================] - 0s - loss: 0.1630 - categorical_accuracy: 0.7393 - val_loss: 0.1866 - val_categorical_accuracy: 0.7114
# Epoch 951/1000
# 468/468 [==============================] - 0s - loss: 0.1839 - categorical_accuracy: 0.6709 - val_loss: 0.2055 - val_categorical_accuracy: 0.6517
# Epoch 952/1000
# 468/468 [==============================] - 0s - loss: 0.1772 - categorical_accuracy: 0.6944 - val_loss: 0.1939 - val_categorical_accuracy: 0.6617
# Epoch 953/1000
# 468/468 [==============================] - 0s - loss: 0.1560 - categorical_accuracy: 0.7436 - val_loss: 0.1392 - val_categorical_accuracy: 0.7662
# Epoch 954/1000
# 468/468 [==============================] - 0s - loss: 0.1653 - categorical_accuracy: 0.7158 - val_loss: 0.1998 - val_categorical_accuracy: 0.7015
# Epoch 955/1000
# 468/468 [==============================] - 0s - loss: 0.1590 - categorical_accuracy: 0.7393 - val_loss: 0.1515 - val_categorical_accuracy: 0.7662
# Epoch 956/1000
# 468/468 [==============================] - 0s - loss: 0.1600 - categorical_accuracy: 0.7521 - val_loss: 0.1908 - val_categorical_accuracy: 0.7114
# Epoch 957/1000
# 468/468 [==============================] - 0s - loss: 0.1604 - categorical_accuracy: 0.7329 - val_loss: 0.1886 - val_categorical_accuracy: 0.7264
# Epoch 958/1000
# 468/468 [==============================] - 0s - loss: 0.1573 - categorical_accuracy: 0.7350 - val_loss: 0.1558 - val_categorical_accuracy: 0.7562
# Epoch 959/1000
# 468/468 [==============================] - 0s - loss: 0.1670 - categorical_accuracy: 0.7286 - val_loss: 0.1531 - val_categorical_accuracy: 0.7463
# Epoch 960/1000
# 468/468 [==============================] - 0s - loss: 0.1670 - categorical_accuracy: 0.7137 - val_loss: 0.1507 - val_categorical_accuracy: 0.7413
# Epoch 961/1000
# 468/468 [==============================] - 0s - loss: 0.1613 - categorical_accuracy: 0.7415 - val_loss: 0.1766 - val_categorical_accuracy: 0.7264
# Epoch 962/1000
# 468/468 [==============================] - 0s - loss: 0.1549 - categorical_accuracy: 0.7564 - val_loss: 0.1669 - val_categorical_accuracy: 0.7363
# Epoch 963/1000
# 468/468 [==============================] - 0s - loss: 0.1501 - categorical_accuracy: 0.7585 - val_loss: 0.1265 - val_categorical_accuracy: 0.8308
# Epoch 964/1000
# 468/468 [==============================] - 0s - loss: 0.1187 - categorical_accuracy: 0.8184 - val_loss: 0.0895 - val_categorical_accuracy: 0.9154
# Epoch 965/1000
# 468/468 [==============================] - 0s - loss: 0.1335 - categorical_accuracy: 0.7949 - val_loss: 0.1505 - val_categorical_accuracy: 0.7612
# Epoch 966/1000
# 468/468 [==============================] - 0s - loss: 0.1243 - categorical_accuracy: 0.8226 - val_loss: 0.1301 - val_categorical_accuracy: 0.8109
# Epoch 967/1000
# 468/468 [==============================] - 0s - loss: 0.1260 - categorical_accuracy: 0.8120 - val_loss: 0.0980 - val_categorical_accuracy: 0.8756
# Epoch 968/1000
# 468/468 [==============================] - 0s - loss: 0.1173 - categorical_accuracy: 0.8184 - val_loss: 0.0915 - val_categorical_accuracy: 0.9005
# Epoch 969/1000
# 468/468 [==============================] - 0s - loss: 0.1257 - categorical_accuracy: 0.8162 - val_loss: 0.1095 - val_categorical_accuracy: 0.8507
# Epoch 970/1000
# 468/468 [==============================] - 0s - loss: 0.1152 - categorical_accuracy: 0.8205 - val_loss: 0.1080 - val_categorical_accuracy: 0.8557
# Epoch 971/1000
# 468/468 [==============================] - 0s - loss: 0.1146 - categorical_accuracy: 0.8226 - val_loss: 0.1468 - val_categorical_accuracy: 0.7562
# Epoch 972/1000
# 468/468 [==============================] - 0s - loss: 0.1341 - categorical_accuracy: 0.8034 - val_loss: 0.1171 - val_categorical_accuracy: 0.8458
# Epoch 973/1000
# 468/468 [==============================] - 0s - loss: 0.1176 - categorical_accuracy: 0.8162 - val_loss: 0.1143 - val_categorical_accuracy: 0.8557
# Epoch 974/1000
# 468/468 [==============================] - 0s - loss: 0.1268 - categorical_accuracy: 0.7991 - val_loss: 0.1393 - val_categorical_accuracy: 0.8159
# Epoch 975/1000
# 468/468 [==============================] - 0s - loss: 0.1799 - categorical_accuracy: 0.6923 - val_loss: 0.1949 - val_categorical_accuracy: 0.7065
# Epoch 976/1000
# 468/468 [==============================] - 0s - loss: 0.1340 - categorical_accuracy: 0.8205 - val_loss: 0.0996 - val_categorical_accuracy: 0.8905
# Epoch 977/1000
# 468/468 [==============================] - 0s - loss: 0.1137 - categorical_accuracy: 0.8333 - val_loss: 0.1126 - val_categorical_accuracy: 0.8557
# Epoch 978/1000
# 468/468 [==============================] - 0s - loss: 0.1208 - categorical_accuracy: 0.8333 - val_loss: 0.1009 - val_categorical_accuracy: 0.8856
# Epoch 979/1000
# 468/468 [==============================] - 0s - loss: 0.1146 - categorical_accuracy: 0.8397 - val_loss: 0.1499 - val_categorical_accuracy: 0.7960
# Epoch 980/1000
# 468/468 [==============================] - 0s - loss: 0.1881 - categorical_accuracy: 0.7137 - val_loss: 0.1432 - val_categorical_accuracy: 0.7761
# Epoch 981/1000
# 468/468 [==============================] - 0s - loss: 0.1474 - categorical_accuracy: 0.7628 - val_loss: 0.1715 - val_categorical_accuracy: 0.7214
# Epoch 982/1000
# 468/468 [==============================] - 0s - loss: 0.1245 - categorical_accuracy: 0.8056 - val_loss: 0.1370 - val_categorical_accuracy: 0.8308
# Epoch 983/1000
# 468/468 [==============================] - 0s - loss: 0.1140 - categorical_accuracy: 0.8269 - val_loss: 0.1075 - val_categorical_accuracy: 0.8806
# Epoch 984/1000
# 468/468 [==============================] - 0s - loss: 0.1307 - categorical_accuracy: 0.8120 - val_loss: 0.1182 - val_categorical_accuracy: 0.8557
# Epoch 985/1000
# 468/468 [==============================] - 0s - loss: 0.1132 - categorical_accuracy: 0.8397 - val_loss: 0.1072 - val_categorical_accuracy: 0.8756
# Epoch 986/1000
# 468/468 [==============================] - 0s - loss: 0.1228 - categorical_accuracy: 0.8291 - val_loss: 0.1256 - val_categorical_accuracy: 0.8109
# Epoch 987/1000
# 468/468 [==============================] - 0s - loss: 0.1088 - categorical_accuracy: 0.8397 - val_loss: 0.0813 - val_categorical_accuracy: 0.9055
# Epoch 988/1000
# 468/468 [==============================] - 0s - loss: 0.1249 - categorical_accuracy: 0.7991 - val_loss: 0.1085 - val_categorical_accuracy: 0.8458
# Epoch 989/1000
# 468/468 [==============================] - 0s - loss: 0.1028 - categorical_accuracy: 0.8654 - val_loss: 0.1025 - val_categorical_accuracy: 0.8706
# Epoch 990/1000
# 468/468 [==============================] - 0s - loss: 0.1186 - categorical_accuracy: 0.8269 - val_loss: 0.1085 - val_categorical_accuracy: 0.8259
# Epoch 991/1000
# 468/468 [==============================] - 0s - loss: 0.1291 - categorical_accuracy: 0.8077 - val_loss: 0.1073 - val_categorical_accuracy: 0.8706
# Epoch 992/1000
# 468/468 [==============================] - 0s - loss: 0.1243 - categorical_accuracy: 0.8141 - val_loss: 0.1445 - val_categorical_accuracy: 0.8060
# Epoch 993/1000
# 468/468 [==============================] - 0s - loss: 0.1370 - categorical_accuracy: 0.7906 - val_loss: 0.1341 - val_categorical_accuracy: 0.7811
# Epoch 994/1000
# 468/468 [==============================] - 0s - loss: 0.1690 - categorical_accuracy: 0.7564 - val_loss: 0.1238 - val_categorical_accuracy: 0.8209
# Epoch 995/1000
# 468/468 [==============================] - 0s - loss: 0.1221 - categorical_accuracy: 0.8184 - val_loss: 0.1175 - val_categorical_accuracy: 0.8458
# Epoch 996/1000
# 468/468 [==============================] - 0s - loss: 0.1122 - categorical_accuracy: 0.8376 - val_loss: 0.0968 - val_categorical_accuracy: 0.8905
# Epoch 997/1000
# 468/468 [==============================] - 0s - loss: 0.1372 - categorical_accuracy: 0.7885 - val_loss: 0.1654 - val_categorical_accuracy: 0.7313
# Epoch 998/1000
# 468/468 [==============================] - 0s - loss: 0.1127 - categorical_accuracy: 0.8440 - val_loss: 0.0913 - val_categorical_accuracy: 0.9055
# Epoch 999/1000
# 468/468 [==============================] - 0s - loss: 0.1358 - categorical_accuracy: 0.7863 - val_loss: 0.1512 - val_categorical_accuracy: 0.7512
# Epoch 1000/1000
# 468/468 [==============================] - 0s - loss: 0.1233 - categorical_accuracy: 0.8162 - val_loss: 0.1450 - val_categorical_accuracy: 0.7861

# %%
# when training is complete, plot the graph of accuracy and loss against number training examples

#  "Accuracy"
plt.plot(t_num,acc_values)
plt.plot(t_num,val_acc_values)
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('n_examples')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# "Loss"
plt.plot(t_num,loss_values)
plt.plot(t_num,val_loss_values)
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('n_examples')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
plotevery = 10
print(history.history.keys())
#  "Accuracy"
plt.plot(history.history['categorical_accuracy'][::plotevery])
plt.plot(history.history['val_categorical_accuracy'][::plotevery])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# "Loss"
plt.plot(history.history['loss'][::plotevery])
plt.plot(history.history['val_loss'][::plotevery])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-b134cf056394> in <module>()
#       1 plotevery = 10
# ----> 2 print(history.history.keys())
#       3 #  "Accuracy"
#       4 plt.plot(history.history['categorical_accuracy'][::plotevery])
#       5 plt.plot(history.history['val_categorical_accuracy'][::plotevery])
#
# AttributeError: 'NoneType' object has no attribute 'history'

# %%
scores = model.evaluate(test_x, test_y)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 19/19 [==============================] - 0s
#
# categorical_accuracy: 47.37%

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_44 (Dense)             (None, 64)                2496
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_45 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_46 (Dense)             (None, 9)                 297
# =================================================================
# Total params: 4,873
# Trainable params: 4,873
# Non-trainable params: 0
# _________________________________________________________________

# %%
def updateTestData():
    test_x, test_y = parse_audio_files(root_path_small)
    test_x, test_y = randomize(test_x, test_y)
    test_y = one_hot_encode(test_y)
    return test_x,test_y

def run_prediction(update=False):
    global test_x,test_y
    if update:
        test_x, test_y = updateTestData()
    y_prob = model.predict(test_x)
    y_classes = y_prob.argmax(axis=-1)
#     print(y_classes)
#     print(test_y)
    correct = np.sum((np.where(test_y == 1)[1] == y_classes).astype(np.int8),0)
    wrong = np.sum((np.where(test_y == 1)[1] != y_classes).astype(np.int8),0)
    print('correctly predicted = %s'%correct)
    print('incorrectly predicted = %s'%wrong)

# %%
run_prediction(update=True)
# Out:
# correctly predicted = 8
# incorrectly predicted = 11

# %% [markdown]
# ## Generate Extensive Dataset

# %%
import wave

import numpy
sr = 22050 # sample rate
T = 0.125    # seconds
freq = 0 # for empty sound
pi = numpy.pi
t = numpy.linspace(0, T, int(T*sr), endpoint=False) # time variable
half_empty = 0.5*numpy.sin(2*pi*freq*t)
one_empty = np.append(half_empty, half_empty)
quarter_sample_shape = int(half_empty.shape[0] / 2)

def write_file(X, name, ext, uid):
    new_filename = "{name}{uid}{ext}".format(name=name, uid=uid, ext=ext)
    librosa.output.write_wav(new_filename, X, sr)
    print('file created - %s'%new_filename)
    
def create_trimmed_file(filename):
    X, sample_rate = librosa.load(filename)
    if(sample_rate != sr):
        print('\x1b[5;30;41m' + 'Please check the sampling rate' + '\x1b[0m')
        return
        
    # get the samples to be padded
    name, ext = os.path.splitext(filename)
    
    # translate with empty padding
    X1 = X[:-1*half_empty.shape[0]]
    uid='_right_trimmed'
    write_file(X1, name, ext, uid)
    
    X2 = X[:-1*one_empty.shape[0]]
    uid='_right_2_trimmed'
    write_file(X2, name, ext, uid)
    
    X3 = X[half_empty.shape[0]:]
    uid='_left_trimmed'
    write_file(X3, name, ext, uid)
    
    X4 = X[one_empty.shape[0]:]
    uid='_left_2_trimmed'
    write_file(X4, name, ext, uid)
    
    X5 = X[one_empty.shape[0]:-1*one_empty.shape[0]]
    uid='lr_2_trimmed'
    write_file(X5, name, ext, uid)
    
    X6 = X[half_empty.shape[0]:-1*half_empty.shape[0]]
    uid='lr_trimmed'
    write_file(X6, name, ext, uid)

# iterate over all files
def translate_file(filename, add_sound_padding=False):

    X, sample_rate = librosa.load(filename)
    if(sample_rate != sr):
        print('\x1b[5;30;41m' + 'Please check the sampling rate' + '\x1b[0m')
        return
        
    # get the samples to be padded
    name, ext = os.path.splitext(filename)
    quarter_sample = X[-1*quarter_sample_shape:]
    half_sample = np.append(quarter_sample, quarter_sample)
    one_sample = np.append(half_sample, half_sample)
    
    # translate with empty padding
    X1 = np.append(half_empty, X[:-1*half_empty.shape[0]])
    uid='_right_e'
    write_file(X1, name, ext, uid)
    
    X2 = np.append(one_empty, X[:-1*one_empty.shape[0]])
    uid='_right_2_e'
    write_file(X2, name, ext, uid)
    
    X3 = np.append(X[half_empty.shape[0]:], half_empty)
    uid='_left_e'
    write_file(X3, name, ext, uid)
    X4 = np.append(X[one_empty.shape[0]:], one_empty)
    uid='_left_2_e'
    write_file(X4, name, ext, uid)
    
    #translate with audio ending used as padding
    if add_sound_padding:
        X5 = np.append(half_sample, X[:-1*half_sample.shape[0]])
        uid='_right'
        write_file(X5, name, ext, uid)
        
        X6 = np.append(one_sample, X[:-1*one_sample.shape[0]])
        uid='_right_2'
        write_file(X6, name, ext, uid)
        
        X7 = np.append(X[half_sample.shape[0]:], half_sample)
        uid='_left'
        write_file(X7, name, ext, uid)
        
        X8 = np.append(X[one_sample.shape[0]:], one_sample)
        uid='_left_2'
        write_file(X8, name, ext, uid)

# %%
import matplotlib.pyplot as plt
import librosa.display

def plot_spec(filename):
    print('filename=%s'%filename)
    x, sr = librosa.load(filename)
    plt.figure(figsize=(20, 2))
    plt.title = os.path.basename(os.path.splitext(filename)[0])
    librosa.display.waveplot(x, sr=sr)
    plt.show

# %%
def translate_all_files(root_path):
    file_ext = '*.wav'
    count = 0
    for file in glob.glob(os.path.join(root_path, file_ext)):
        translate_file(os.path.join(root_path, file))
        count=count+1
        print('translated %d files'%count)
        
def trim_all_files(root_path):
    file_ext = '*.wav'
    count = 0
    for file in glob.glob(os.path.join(root_path, file_ext)):
        create_trimmed_file(os.path.join(root_path, file))
        count=count+1
        print('trimmed %d files'%count)

# %%
translate_all_files('/home/paperspace/Dropbox/notebook/sounds/recorded/small/ah_drakht_boht_sohna_lag_reha/') #1
translate_all_files('/home/paperspace/Dropbox/notebook/sounds/recorded/small/ah_gana_download_kar/') #2
translate_all_files('/home/paperspace/Dropbox/notebook/sounds/recorded/small/balli_ik_kam_kar/') #3
translate_all_files('/home/paperspace/Dropbox/notebook/sounds/recorded/small/kuch_nava_try_karo/') #4
translate_all_files('/home/paperspace/Dropbox/notebook/sounds/recorded/small/last_sample/') #5
translate_all_files('/home/paperspace/Dropbox/notebook/sounds/recorded/small/mausam_vadia_ajj/') #6
translate_all_files('/home/paperspace/Dropbox/notebook/sounds/recorded/small/parkhin_na_pahunch_jatt_di/') #7
translate_all_files('/home/paperspace/Dropbox/notebook/sounds/recorded/small/tathe_nu_phone_la/') #8
translate_all_files('/home/paperspace/Dropbox/notebook/sounds/recorded/small/thoda_ja_lamba_phrase/') #9
'''
translate_all_files('/Users/Gundeep/Dropbox/notebook/sounds/recorded/large/ah_drakht_boht_sohna_lag_reha/') #1
translate_all_files('/Users/Gundeep/Dropbox/notebook/sounds/recorded/large/ah_gana_download_kar/') #2
translate_all_files('/Users/Gundeep/Dropbox/notebook/sounds/recorded/large/balli_ik_kam_kar/') #3
translate_all_files('/Users/Gundeep/Dropbox/notebook/sounds/recorded/large/kuch_nava_try_karo/') #4
translate_all_files('/Users/Gundeep/Dropbox/notebook/sounds/recorded/large/last_sample/') #5
translate_all_files('/Users/Gundeep/Dropbox/notebook/sounds/recorded/large/mausam_vadia_ajj/') #6
translate_all_files('/Users/Gundeep/Dropbox/notebook/sounds/recorded/large/parkhin_na_pahunch_jatt_di/') #7
translate_all_files('/Users/Gundeep/Dropbox/notebook/sounds/recorded/large/tathe_nu_phone_la/') #8
translate_all_files('/Users/Gundeep/Dropbox/notebook/sounds/recorded/large/thoda_ja_lamba_phrase/') #9
'''
# Out:
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/ah_drakht_boht_sohna_lag_reha/1_right_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/ah_drakht_boht_sohna_lag_reha/1_right_2_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/ah_drakht_boht_sohna_lag_reha/1_left_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/ah_drakht_boht_sohna_lag_reha/1_left_2_e.wav
# translated 1 files
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/ah_drakht_boht_sohna_lag_reha/2_right_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/ah_drakht_boht_sohna_lag_reha/2_right_2_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/ah_drakht_boht_sohna_lag_reha/2_left_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/ah_drakht_boht_sohna_lag_reha/2_left_2_e.wav
# translated 2 files
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/ah_gana_download_kar/3_right_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/ah_gana_download_kar/3_right_2_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/ah_gana_download_kar/3_left_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/ah_gana_download_kar/3_left_2_e.wav
# translated 1 files
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/ah_gana_download_kar/2_right_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/ah_gana_download_kar/2_right_2_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/ah_gana_download_kar/2_left_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/ah_gana_download_kar/2_left_2_e.wav
# translated 2 files
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/ah_gana_download_kar/17_clean_right_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/ah_gana_download_kar/17_clean_right_2_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/ah_gana_download_kar/17_clean_left_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/ah_gana_download_kar/17_clean_left_2_e.wav
# translated 3 files
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/balli_ik_kam_kar/4_right_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/balli_ik_kam_kar/4_right_2_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/balli_ik_kam_kar/4_left_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/balli_ik_kam_kar/4_left_2_e.wav
# translated 1 files
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/balli_ik_kam_kar/3_right_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/balli_ik_kam_kar/3_right_2_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/balli_ik_kam_kar/3_left_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/balli_ik_kam_kar/3_left_2_e.wav
# translated 2 files
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/kuch_nava_try_karo/5_right_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/kuch_nava_try_karo/5_right_2_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/kuch_nava_try_karo/5_left_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/kuch_nava_try_karo/5_left_2_e.wav
# translated 1 files
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/kuch_nava_try_karo/4_right_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/kuch_nava_try_karo/4_right_2_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/kuch_nava_try_karo/4_left_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/kuch_nava_try_karo/4_left_2_e.wav
# translated 2 files
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/last_sample/6_right_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/last_sample/6_right_2_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/last_sample/6_left_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/last_sample/6_left_2_e.wav
# translated 1 files
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/last_sample/5_right_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/last_sample/5_right_2_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/last_sample/5_left_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/last_sample/5_left_2_e.wav
# translated 2 files
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/mausam_vadia_ajj/6_right_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/mausam_vadia_ajj/6_right_2_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/mausam_vadia_ajj/6_left_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/mausam_vadia_ajj/6_left_2_e.wav
# translated 1 files
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/mausam_vadia_ajj/7_right_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/mausam_vadia_ajj/7_right_2_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/mausam_vadia_ajj/7_left_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/mausam_vadia_ajj/7_left_2_e.wav
# translated 2 files
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/parkhin_na_pahunch_jatt_di/8_right_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/parkhin_na_pahunch_jatt_di/8_right_2_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/parkhin_na_pahunch_jatt_di/8_left_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/parkhin_na_pahunch_jatt_di/8_left_2_e.wav
# translated 1 files
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/parkhin_na_pahunch_jatt_di/7_right_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/parkhin_na_pahunch_jatt_di/7_right_2_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/parkhin_na_pahunch_jatt_di/7_left_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/parkhin_na_pahunch_jatt_di/7_left_2_e.wav
# translated 2 files
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/tathe_nu_phone_la/8_right_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/tathe_nu_phone_la/8_right_2_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/tathe_nu_phone_la/8_left_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/tathe_nu_phone_la/8_left_2_e.wav
# translated 1 files
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/tathe_nu_phone_la/9_right_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/tathe_nu_phone_la/9_right_2_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/tathe_nu_phone_la/9_left_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/tathe_nu_phone_la/9_left_2_e.wav
# translated 2 files
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/thoda_ja_lamba_phrase/11_right_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/thoda_ja_lamba_phrase/11_right_2_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/thoda_ja_lamba_phrase/11_left_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/thoda_ja_lamba_phrase/11_left_2_e.wav
# translated 1 files
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/thoda_ja_lamba_phrase/9_right_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/thoda_ja_lamba_phrase/9_right_2_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/thoda_ja_lamba_phrase/9_left_e.wav
# file created - /home/paperspace/Dropbox/notebook/sounds/recorded/small/thoda_ja_lamba_phrase/9_left_2_e.wav
# translated 2 files
# "\ntranslate_all_files('/Users/Gundeep/Dropbox/notebook/sounds/recorded/large/ah_drakht_boht_sohna_lag_reha/') #1\ntranslate_all_files('/Users/Gundeep/Dropbox/notebook/sounds/recorded/large/ah_gana_download_kar/') #2\ntranslate_all_files('/Users/Gundeep/Dropbox/notebook/sounds/recorded/large/balli_ik_kam_kar/') #3\ntranslate_all_files('/Users/Gundeep/Dropbox/notebook/sounds/recorded/large/kuch_nava_try_karo/') #4\ntranslate_all_files('/Users/Gundeep/Dropbox/notebook/sounds/recorded/large/last_sample/') #5\ntranslate_all_files('/Users/Gundeep/Dropbox/notebook/sounds/recorded/large/mausam_vadia_ajj/') #6\ntranslate_all_files('/Users/Gundeep/Dropbox/notebook/sounds/recorded/large/parkhin_na_pahunch_jatt_di/') #7\ntranslate_all_files('/Users/Gundeep/Dropbox/notebook/sounds/recorded/large/tathe_nu_phone_la/') #8\ntranslate_all_files('/Users/Gundeep/Dropbox/notebook/sounds/recorded/large/thoda_ja_lamba_phrase/') #9\n"
